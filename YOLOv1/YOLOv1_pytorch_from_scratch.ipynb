# %%
"""Download Cat-Dog dataset"""

# !curl -L https://public.roboflow.com/ds/B1cLXyUA5l?key=0E7jZ1cq7I > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/Sphynx_205_jpg.rf.f7c5a41130f3916deed35f974c5d1df8.txt
#  extracting: train/_darknet.labels
#  extracting: train/american_bulldog_102_jpg.rf.f5d69d3ce15f380432ee6418448c144a.jpg
#  extracting: train/american_bulldog_102_jpg.rf.f5d69d3ce15f380432ee6418448c144a.txt
#  extracting: train/american_bulldog_104_jpg.rf.bd70dd5517696c5dfac1440ef69b0a7a.jpg
#  extracting: train/american_bulldog_104_jpg.rf.bd70dd5517696c5dfac1440ef69b0a7a.txt
#  extracting: train/american_bulldog_105_jpg.rf.7ff447c13447606deeab8329f180fe49.jpg
#  extracting: train/american_bulldog_105_jpg.rf.7ff447c13447606deeab8329f180fe49.txt
#  extracting: train/american_bulldog_106_jpg.rf.d5fdd6a7aab0505920adc58d2efa1793.jpg
#  extracting: train/american_bulldog_106_jpg.rf.d5fdd6a7aab0505920adc58d2efa1793.txt
#  extracting: train/american_bulldog_108_jpg.rf.5a524854d95e3c261abae43faa6b2e0f.jpg
#  extracting: train/american_bulldog_108_jpg.rf.5a524854d95e3c261abae43faa6b2e0f.txt
#  extracting: train/american_bulldog_109_jpg.rf.c1d13dacdd6dfe7ee814a989f6fe3802.jpg
#  extracting: train/american_bulldog_109_jpg.rf.c1d13dacdd6dfe7ee814a989f6fe3802.txt
#  extracting: train/american_bulldog_110_jpg.rf.eea553ad66c84b53f405346311e84789.jpg
#  extracting: train/american_bulldog_110_jpg.rf.eea553ad66c84b53f405346311e84789.txt
#  extracting: train/american_bulldog_112_jpg.rf.b77a8201aec6eed208e2c988edee59fd.jpg
#  extracting: train/american_bulldog_112_jpg.rf.b77a8201aec6eed208e2c988edee59fd.txt
#  extracting: train/american_bulldog_113_jpg.rf.fbb760ba752231d4069a532342934743.jpg
#  extracting: train/american_bulldog_113_jpg.rf.fbb760ba752231d4069a532342934743.txt
#  extracting: train/american_bulldog_114_jpg.rf.af79f2d403da4b0b60c8d99581a5dd0c.jpg
#  extracting: train/american_bulldog_114_jpg.rf.af79f2d403da4b0b60c8d99581a5dd0c.txt
#  extracting: train/american_bulldog_119_jpg.rf.401188c694c1ded9f154a12e27135c7c.jpg
#  extracting: train/american_bulldog_119_jpg.rf.401188c694c1ded9f154a12e27135c7c.txt
#  extracting: train/american_bulldog_11_jpg.rf.303a2fa998d45fd9c815635808910266.jpg
#  extracting: train/american_bulldog_11_jpg.rf.303a2fa998d45fd9c815635808910266.txt
#  extracting: train/american_bulldog_120_jpg.rf.109f9b93704ca08ac2aed1d3b6e47357.jpg
#  extracting: train/american_bulldog_120_jpg.rf.109f9b93704ca08ac2aed1d3b6e47357.txt
#  extracting: train/american_bulldog_121_jpg.rf.b86b63c6572516c33a1d552f72723910.jpg
#  extracting: train/american_bulldog_121_jpg.rf.b86b63c6572516c33a1d552f72723910.txt
#  extracting: train/american_bulldog_123_jpg.rf.a2f7494fee3ca04dabedb3e2a6dd0e7f.jpg
#  extracting: train/american_bulldog_123_jpg.rf.a2f7494fee3ca04dabedb3e2a6dd0e7f.txt
#  extracting: train/american_bulldog_124_jpg.rf.255bbc189e75ce89c6e9ca8ba50fcccc.jpg
#  extracting: train/american_bulldog_124_jpg.rf.255bbc189e75ce89c6e9ca8ba50fcccc.txt
#  extracting: train/american_bulldog_125_jpg.rf.52430400f744facbe3c74c6dd8c64bec.jpg
#  extracting: train/american_bulldog_125_jpg.rf.52430400f744facbe3c74c6dd8c64bec.txt
#  extracting: train/american_bulldog_129_jpg.rf.937549a115dedfe4b56329a10cc6d303.jpg
#  extracting: train/american_bulldog_129_jpg.rf.937549a115dedfe4b56329a10cc6d303.txt
#  extracting: train/american_bulldog_131_jpg.rf.eb7d3d358fa884643b6423384915e0c0.jpg
#  extracting: train/american_bulldog_131_jpg.rf.eb7d3d358fa884643b6423384915e0c0.txt
#  extracting: train/american_bulldog_132_jpg.rf.8368687987c81b80c7c2cdf8dc2816ae.jpg
#  extracting: train/american_bulldog_132_jpg.rf.8368687987c81b80c7c2cdf8dc2816ae.txt
#  extracting: train/american_bulldog_133_jpg.rf.6210255699b312cd695a556971b66114.jpg
#  extracting: train/american_bulldog_133_jpg.rf.6210255699b312cd695a556971b66114.txt
#  extracting: train/american_bulldog_134_jpg.rf.3078a451a4b30afaa1c49f18cc4f833b.jpg
#  extracting: train/american_bulldog_134_jpg.rf.3078a451a4b30afaa1c49f18cc4f833b.txt
#  extracting: train/american_bulldog_136_jpg.rf.f46b72ef8e913313a00edb00c553a288.jpg
#  extracting: train/american_bulldog_136_jpg.rf.f46b72ef8e913313a00edb00c553a288.txt
#  extracting: train/american_bulldog_137_jpg.rf.348ad065d50c345e51724ed4ddfb4a0c.jpg
#  extracting: train/american_bulldog_137_jpg.rf.348ad065d50c345e51724ed4ddfb4a0c.txt
#  extracting: train/american_bulldog_139_jpg.rf.1b6e5476580ae1bcd885d9c75db4c374.jpg
#  extracting: train/american_bulldog_139_jpg.rf.1b6e5476580ae1bcd885d9c75db4c374.txt
#  extracting: train/american_bulldog_13_jpg.rf.30a10348248c3f0c7c906cc696a69a6e.jpg
#  extracting: train/american_bulldog_13_jpg.rf.30a10348248c3f0c7c906cc696a69a6e.txt
#  extracting: train/american_bulldog_140_jpg.rf.57f444f557974172660963de7bb842fd.jpg
#  extracting: train/american_bulldog_140_jpg.rf.57f444f557974172660963de7bb842fd.txt
#  extracting: train/american_bulldog_141_jpg.rf.41cd9387675bd2e5253838680080102f.jpg
#  extracting: train/american_bulldog_141_jpg.rf.41cd9387675bd2e5253838680080102f.txt
#  extracting: train/american_bulldog_143_jpg.rf.cbbbcc941d13e97f3eb7dca77b884361.jpg
#  extracting: train/american_bulldog_143_jpg.rf.cbbbcc941d13e97f3eb7dca77b884361.txt
#  extracting: train/american_bulldog_146_jpg.rf.8720c253fbb839c119848562de741d17.jpg
#  extracting: train/american_bulldog_146_jpg.rf.8720c253fbb839c119848562de741d17.txt
#  extracting: train/american_bulldog_147_jpg.rf.6c922b28a2c83b3c4f2b099b68c18b4b.jpg
#  extracting: train/american_bulldog_147_jpg.rf.6c922b28a2c83b3c4f2b099b68c18b4b.txt
#  extracting: train/american_bulldog_150_jpg.rf.9d7899c51f389dd54466ba4febb0f07a.jpg
#  extracting: train/american_bulldog_150_jpg.rf.9d7899c51f389dd54466ba4febb0f07a.txt
#  extracting: train/american_bulldog_151_jpg.rf.bd0037bf9df7b11645847391b8b509ba.jpg
#  extracting: train/american_bulldog_151_jpg.rf.bd0037bf9df7b11645847391b8b509ba.txt
#  extracting: train/american_bulldog_152_jpg.rf.5169dc1686ec798b51f6136b7b869fa9.jpg
#  extracting: train/american_bulldog_152_jpg.rf.5169dc1686ec798b51f6136b7b869fa9.txt
#  extracting: train/american_bulldog_153_jpg.rf.ac2d9d5e6d11248d6fab48f2ff627444.jpg
#  extracting: train/american_bulldog_153_jpg.rf.ac2d9d5e6d11248d6fab48f2ff627444.txt
#  extracting: train/american_bulldog_161_jpg.rf.cf64a1e2988190324aa9a9d872d1061c.jpg
#  extracting: train/american_bulldog_161_jpg.rf.cf64a1e2988190324aa9a9d872d1061c.txt
#  extracting: train/american_bulldog_164_jpg.rf.50b9816cb97af377ebd5a75edce809d4.jpg
#  extracting: train/american_bulldog_164_jpg.rf.50b9816cb97af377ebd5a75edce809d4.txt
#  extracting: train/american_bulldog_166_jpg.rf.40d2a740054ebce318b5eb0e0298a09e.jpg
#  extracting: train/american_bulldog_166_jpg.rf.40d2a740054ebce318b5eb0e0298a09e.txt
#  extracting: train/american_bulldog_167_jpg.rf.148072d7a7a7fe9dd5030262544b785a.jpg
#  extracting: train/american_bulldog_167_jpg.rf.148072d7a7a7fe9dd5030262544b785a.txt
#  extracting: train/american_bulldog_168_jpg.rf.d8b33d74d6f160701ebf6c0af0c63ea8.jpg
#  extracting: train/american_bulldog_168_jpg.rf.d8b33d74d6f160701ebf6c0af0c63ea8.txt
#  extracting: train/american_bulldog_16_jpg.rf.46514b6b78605de98942fba15705dfa6.jpg
#  extracting: train/american_bulldog_16_jpg.rf.46514b6b78605de98942fba15705dfa6.txt
#  extracting: train/american_bulldog_171_jpg.rf.899490fd88983aa7cc2a039ab916dc99.jpg
#  extracting: train/american_bulldog_171_jpg.rf.899490fd88983aa7cc2a039ab916dc99.txt
#  extracting: train/american_bulldog_172_jpg.rf.4a87689844bf9ebd7944ea0c18beab25.jpg
#  extracting: train/american_bulldog_172_jpg.rf.4a87689844bf9ebd7944ea0c18beab25.txt
#  extracting: train/american_bulldog_174_jpg.rf.6cf6ff3b7e03a42fe405a82aeed7b8d4.jpg
#  extracting: train/american_bulldog_174_jpg.rf.6cf6ff3b7e03a42fe405a82aeed7b8d4.txt
#  extracting: train/american_bulldog_175_jpg.rf.52419745d7c72d2aae120be5fcee771a.jpg
#  extracting: train/american_bulldog_175_jpg.rf.52419745d7c72d2aae120be5fcee771a.txt
#  extracting: train/american_bulldog_177_jpg.rf.2abd2064cd6dfac7936a1af3bb15b482.jpg
#  extracting: train/american_bulldog_177_jpg.rf.2abd2064cd6dfac7936a1af3bb15b482.txt
#  extracting: train/american_bulldog_179_jpg.rf.d29d3ad291b700fd525f4273151583dd.jpg
#  extracting: train/american_bulldog_179_jpg.rf.d29d3ad291b700fd525f4273151583dd.txt
#  extracting: train/american_bulldog_180_jpg.rf.9fbf3c7411581039cc077e473a656c0d.jpg
#  extracting: train/american_bulldog_180_jpg.rf.9fbf3c7411581039cc077e473a656c0d.txt
#  extracting: train/american_bulldog_182_jpg.rf.fd71a7e3e2b6079e555fecee73533a03.jpg
#  extracting: train/american_bulldog_182_jpg.rf.fd71a7e3e2b6079e555fecee73533a03.txt
#  extracting: train/american_bulldog_183_jpg.rf.a32f1203bd8b9bf3872d5dd3220e74b5.jpg
#  extracting: train/american_bulldog_183_jpg.rf.a32f1203bd8b9bf3872d5dd3220e74b5.txt
#  extracting: train/american_bulldog_185_jpg.rf.16cf04c102e11a5e9612833f2c8c8a36.jpg
#  extracting: train/american_bulldog_185_jpg.rf.16cf04c102e11a5e9612833f2c8c8a36.txt
#  extracting: train/american_bulldog_186_jpg.rf.14c81fa6a959c406252d76c51ae4439e.jpg
#  extracting: train/american_bulldog_186_jpg.rf.14c81fa6a959c406252d76c51ae4439e.txt
#  extracting: train/american_bulldog_187_jpg.rf.9db3fcf2ef177eb71f8cf814c0450251.jpg
#  extracting: train/american_bulldog_187_jpg.rf.9db3fcf2ef177eb71f8cf814c0450251.txt
#  extracting: train/american_bulldog_188_jpg.rf.249313f4cb682e4f8f0c015c17768dde.jpg
#  extracting: train/american_bulldog_188_jpg.rf.249313f4cb682e4f8f0c015c17768dde.txt
#  extracting: train/american_bulldog_18_jpg.rf.b9c44666561c9c3fe1c60cad323cf475.jpg
#  extracting: train/american_bulldog_18_jpg.rf.b9c44666561c9c3fe1c60cad323cf475.txt
#  extracting: train/american_bulldog_191_jpg.rf.2e9f86b9dea25ca4be907233c38d44e7.jpg
#  extracting: train/american_bulldog_191_jpg.rf.2e9f86b9dea25ca4be907233c38d44e7.txt
#  extracting: train/american_bulldog_192_jpg.rf.ad5cd6cf113ac4aea01e1bc36e272536.jpg
#  extracting: train/american_bulldog_192_jpg.rf.ad5cd6cf113ac4aea01e1bc36e272536.txt
#  extracting: train/american_bulldog_193_jpg.rf.0418f52d14814775e94641b7ffef78f9.jpg
#  extracting: train/american_bulldog_193_jpg.rf.0418f52d14814775e94641b7ffef78f9.txt
#  extracting: train/american_bulldog_194_jpg.rf.c1c3b647376005344da859e9e15c0363.jpg
#  extracting: train/american_bulldog_194_jpg.rf.c1c3b647376005344da859e9e15c0363.txt
#  extracting: train/american_bulldog_196_jpg.rf.9d9297b3e5f637eddcf762a3cde890db.jpg
#  extracting: train/american_bulldog_196_jpg.rf.9d9297b3e5f637eddcf762a3cde890db.txt
#  extracting: train/american_bulldog_197_jpg.rf.045de1286eae8fc242f3488fcb222b3a.jpg
#  extracting: train/american_bulldog_197_jpg.rf.045de1286eae8fc242f3488fcb222b3a.txt
#  extracting: train/american_bulldog_199_jpg.rf.211b9f077d041db938a78dd33474bf56.jpg
#  extracting: train/american_bulldog_199_jpg.rf.211b9f077d041db938a78dd33474bf56.txt
#  extracting: train/american_bulldog_19_jpg.rf.a5a35f910742bcc8581817aaf26d6264.jpg
#  extracting: train/american_bulldog_19_jpg.rf.a5a35f910742bcc8581817aaf26d6264.txt
#  extracting: train/american_bulldog_201_jpg.rf.45808954d11c4c4008ea34b5fcbcc8f4.jpg
#  extracting: train/american_bulldog_201_jpg.rf.45808954d11c4c4008ea34b5fcbcc8f4.txt
#  extracting: train/american_bulldog_202_jpg.rf.e249e20d5f14bc5d06110f6bbc797835.jpg
#  extracting: train/american_bulldog_202_jpg.rf.e249e20d5f14bc5d06110f6bbc797835.txt
#  extracting: train/american_pit_bull_terrier_100_jpg.rf.a81760d358829dff50e3f27b46681570.jpg
#  extracting: train/american_pit_bull_terrier_100_jpg.rf.a81760d358829dff50e3f27b46681570.txt
#  extracting: train/american_pit_bull_terrier_101_jpg.rf.0d8d62e9e181b81cfce154f14b4a54b0.jpg
#  extracting: train/american_pit_bull_terrier_101_jpg.rf.0d8d62e9e181b81cfce154f14b4a54b0.txt
#  extracting: train/american_pit_bull_terrier_103_jpg.rf.ed0a25cae6291067ae4feb991ab0855d.jpg
#  extracting: train/american_pit_bull_terrier_103_jpg.rf.ed0a25cae6291067ae4feb991ab0855d.txt
#  extracting: train/american_pit_bull_terrier_104_jpg.rf.747e90f240f18be726cf916ef66b472f.jpg
#  extracting: train/american_pit_bull_terrier_104_jpg.rf.747e90f240f18be726cf916ef66b472f.txt
#  extracting: train/american_pit_bull_terrier_105_jpg.rf.d81e26b87286acee90f77493222c4a3a.jpg
#  extracting: train/american_pit_bull_terrier_105_jpg.rf.d81e26b87286acee90f77493222c4a3a.txt
#  extracting: train/american_pit_bull_terrier_106_jpg.rf.33078e21c60064e4ea3b2d582ffa2064.jpg
#  extracting: train/american_pit_bull_terrier_106_jpg.rf.33078e21c60064e4ea3b2d582ffa2064.txt
#  extracting: train/american_pit_bull_terrier_107_jpg.rf.e0ba7335c2ee0d47dae821d65ad8fad2.jpg
#  extracting: train/american_pit_bull_terrier_107_jpg.rf.e0ba7335c2ee0d47dae821d65ad8fad2.txt
#  extracting: train/american_pit_bull_terrier_110_jpg.rf.411b3e24dda8cd318b98c0d4848c6109.jpg
#  extracting: train/american_pit_bull_terrier_110_jpg.rf.411b3e24dda8cd318b98c0d4848c6109.txt
#  extracting: train/american_pit_bull_terrier_111_jpg.rf.57f11b9fff0aa25967fee153ded500c7.jpg
#  extracting: train/american_pit_bull_terrier_111_jpg.rf.57f11b9fff0aa25967fee153ded500c7.txt
#  extracting: train/american_pit_bull_terrier_113_jpg.rf.f6c30c6e5d6641ffe1cb045fddc6a44e.jpg
#  extracting: train/american_pit_bull_terrier_113_jpg.rf.f6c30c6e5d6641ffe1cb045fddc6a44e.txt
#  extracting: train/american_pit_bull_terrier_115_jpg.rf.beb6f5d80cf3bcc82064ffd017925177.jpg
#  extracting: train/american_pit_bull_terrier_115_jpg.rf.beb6f5d80cf3bcc82064ffd017925177.txt
#  extracting: train/american_pit_bull_terrier_118_jpg.rf.76045e2bec07cef8a853b51257916464.jpg
#  extracting: train/american_pit_bull_terrier_118_jpg.rf.76045e2bec07cef8a853b51257916464.txt
#  extracting: train/american_pit_bull_terrier_119_jpg.rf.d1c49a2f1daef2f7a7491177438762e0.jpg
#  extracting: train/american_pit_bull_terrier_119_jpg.rf.d1c49a2f1daef2f7a7491177438762e0.txt
#  extracting: train/american_pit_bull_terrier_11_jpg.rf.1351a574c542ef33647335879b3be39b.jpg
#  extracting: train/american_pit_bull_terrier_11_jpg.rf.1351a574c542ef33647335879b3be39b.txt
#  extracting: train/american_pit_bull_terrier_121_jpg.rf.62137fe9052e7641cdc18be26e0bfb91.jpg
#  extracting: train/american_pit_bull_terrier_121_jpg.rf.62137fe9052e7641cdc18be26e0bfb91.txt
#  extracting: train/american_pit_bull_terrier_122_jpg.rf.2eafeefb71398a2c0bd436c0d8eae9b1.jpg
#  extracting: train/american_pit_bull_terrier_122_jpg.rf.2eafeefb71398a2c0bd436c0d8eae9b1.txt
#  extracting: train/american_pit_bull_terrier_123_jpg.rf.8dd1c939cd2b8e650904da9b4ecc884c.jpg
#  extracting: train/american_pit_bull_terrier_123_jpg.rf.8dd1c939cd2b8e650904da9b4ecc884c.txt
#  extracting: train/american_pit_bull_terrier_124_jpg.rf.c17429151340b3d6303fa04c6061c2c0.jpg
#  extracting: train/american_pit_bull_terrier_124_jpg.rf.c17429151340b3d6303fa04c6061c2c0.txt
#  extracting: train/american_pit_bull_terrier_125_jpg.rf.8d40793e44a7553d48338a23c60ad406.jpg
#  extracting: train/american_pit_bull_terrier_125_jpg.rf.8d40793e44a7553d48338a23c60ad406.txt
#  extracting: train/american_pit_bull_terrier_127_jpg.rf.ab7e51a2c074adac59381daefb20f7dd.jpg
#  extracting: train/american_pit_bull_terrier_127_jpg.rf.ab7e51a2c074adac59381daefb20f7dd.txt
#  extracting: train/american_pit_bull_terrier_128_jpg.rf.6c117858671838df4ce9aa428f386d13.jpg
#  extracting: train/american_pit_bull_terrier_128_jpg.rf.6c117858671838df4ce9aa428f386d13.txt
#  extracting: train/american_pit_bull_terrier_129_jpg.rf.8a92d96595aab492aa6c2b4e6cb69fe4.jpg
#  extracting: train/american_pit_bull_terrier_129_jpg.rf.8a92d96595aab492aa6c2b4e6cb69fe4.txt
#  extracting: train/american_pit_bull_terrier_130_jpg.rf.6298c0e615ceae58f3dd7c0ddcfebf78.jpg
#  extracting: train/american_pit_bull_terrier_130_jpg.rf.6298c0e615ceae58f3dd7c0ddcfebf78.txt
#  extracting: train/american_pit_bull_terrier_131_jpg.rf.361bbb25f619a656ba6c457124a8d177.jpg
#  extracting: train/american_pit_bull_terrier_131_jpg.rf.361bbb25f619a656ba6c457124a8d177.txt
#  extracting: train/american_pit_bull_terrier_132_jpg.rf.54d2c671668e11addc04842973b21238.jpg
#  extracting: train/american_pit_bull_terrier_132_jpg.rf.54d2c671668e11addc04842973b21238.txt
#  extracting: train/american_pit_bull_terrier_133_jpg.rf.3d9f4fe367567cbbf7b638c15da711d4.jpg
#  extracting: train/american_pit_bull_terrier_133_jpg.rf.3d9f4fe367567cbbf7b638c15da711d4.txt
#  extracting: train/american_pit_bull_terrier_136_jpg.rf.74411cc8a0a7bc8816dccf14902f33dc.jpg
#  extracting: train/american_pit_bull_terrier_136_jpg.rf.74411cc8a0a7bc8816dccf14902f33dc.txt
#  extracting: train/american_pit_bull_terrier_137_jpg.rf.fee1a559524dc981bf98e33578ec67ae.jpg
#  extracting: train/american_pit_bull_terrier_137_jpg.rf.fee1a559524dc981bf98e33578ec67ae.txt
#  extracting: train/american_pit_bull_terrier_138_jpg.rf.0cb776a078e6ce166d5600514aae5d7a.jpg
#  extracting: train/american_pit_bull_terrier_138_jpg.rf.0cb776a078e6ce166d5600514aae5d7a.txt
#  extracting: train/american_pit_bull_terrier_139_jpg.rf.ac6d28cc5d24228613e2658dbc92b7f5.jpg
#  extracting: train/american_pit_bull_terrier_139_jpg.rf.ac6d28cc5d24228613e2658dbc92b7f5.txt
#  extracting: train/american_pit_bull_terrier_13_jpg.rf.6c5574ca06141424b6787855ba6334f7.jpg
#  extracting: train/american_pit_bull_terrier_13_jpg.rf.6c5574ca06141424b6787855ba6334f7.txt
#  extracting: train/american_pit_bull_terrier_140_jpg.rf.aca66676073a2da71fe467472fcc8091.jpg
#  extracting: train/american_pit_bull_terrier_140_jpg.rf.aca66676073a2da71fe467472fcc8091.txt
#  extracting: train/american_pit_bull_terrier_145_jpg.rf.4369173e407f2fe813f78fb5bf676004.jpg
#  extracting: train/american_pit_bull_terrier_145_jpg.rf.4369173e407f2fe813f78fb5bf676004.txt
#  extracting: train/american_pit_bull_terrier_146_jpg.rf.f81dff856bf9ef54057415eec94f8501.jpg
#  extracting: train/american_pit_bull_terrier_146_jpg.rf.f81dff856bf9ef54057415eec94f8501.txt
#  extracting: train/american_pit_bull_terrier_147_jpg.rf.834968b7b99a68ce796876872846bfbe.jpg
#  extracting: train/american_pit_bull_terrier_147_jpg.rf.834968b7b99a68ce796876872846bfbe.txt
#  extracting: train/american_pit_bull_terrier_148_jpg.rf.25ace5d37d3ea732038ceb42c83f86ac.jpg
#  extracting: train/american_pit_bull_terrier_148_jpg.rf.25ace5d37d3ea732038ceb42c83f86ac.txt
#  extracting: train/american_pit_bull_terrier_149_jpg.rf.0a00feefc96a7a55b30a14d57c3a3c1b.jpg
#  extracting: train/american_pit_bull_terrier_149_jpg.rf.0a00feefc96a7a55b30a14d57c3a3c1b.txt
#  extracting: train/american_pit_bull_terrier_14_jpg.rf.84ca2496701cc66923541009aeb4363b.jpg
#  extracting: train/american_pit_bull_terrier_14_jpg.rf.84ca2496701cc66923541009aeb4363b.txt
#  extracting: train/american_pit_bull_terrier_150_jpg.rf.975d7a4aa08cc88104664854f9b19f7d.jpg
#  extracting: train/american_pit_bull_terrier_150_jpg.rf.975d7a4aa08cc88104664854f9b19f7d.txt
#  extracting: train/american_pit_bull_terrier_151_jpg.rf.9a1f693054276d4be49d4e6437ab0ba7.jpg
#  extracting: train/american_pit_bull_terrier_151_jpg.rf.9a1f693054276d4be49d4e6437ab0ba7.txt
#  extracting: train/american_pit_bull_terrier_153_jpg.rf.6d8270dc1629a5ed4e956fd3cd900c6c.jpg
#  extracting: train/american_pit_bull_terrier_153_jpg.rf.6d8270dc1629a5ed4e956fd3cd900c6c.txt
#  extracting: train/american_pit_bull_terrier_154_jpg.rf.f048b5ead9b87da0f9452acf89daae8d.jpg
#  extracting: train/american_pit_bull_terrier_154_jpg.rf.f048b5ead9b87da0f9452acf89daae8d.txt
#  extracting: train/american_pit_bull_terrier_155_jpg.rf.45086e764888c0e369b3abcf62dc4d80.jpg
#  extracting: train/american_pit_bull_terrier_155_jpg.rf.45086e764888c0e369b3abcf62dc4d80.txt
#  extracting: train/american_pit_bull_terrier_156_jpg.rf.ce8a2066adddd9127c11facbb7e359c5.jpg
#  extracting: train/american_pit_bull_terrier_156_jpg.rf.ce8a2066adddd9127c11facbb7e359c5.txt
#  extracting: train/american_pit_bull_terrier_157_jpg.rf.fff46d946d145d4a8e2bb2fdf661fbf5.jpg
#  extracting: train/american_pit_bull_terrier_157_jpg.rf.fff46d946d145d4a8e2bb2fdf661fbf5.txt
#  extracting: train/american_pit_bull_terrier_159_jpg.rf.7a11e586e0346e3bc134e1399d41ef15.jpg
#  extracting: train/american_pit_bull_terrier_159_jpg.rf.7a11e586e0346e3bc134e1399d41ef15.txt
#  extracting: train/american_pit_bull_terrier_160_jpg.rf.5ac5240ce784b732b9540835cee5b918.jpg
#  extracting: train/american_pit_bull_terrier_160_jpg.rf.5ac5240ce784b732b9540835cee5b918.txt
#  extracting: train/american_pit_bull_terrier_161_jpg.rf.bd78ed1ab4ed32a00dafed7ab625e4b9.jpg
#  extracting: train/american_pit_bull_terrier_161_jpg.rf.bd78ed1ab4ed32a00dafed7ab625e4b9.txt
#  extracting: train/american_pit_bull_terrier_162_jpg.rf.a9e0afa47c063261d566e45058074f01.jpg
#  extracting: train/american_pit_bull_terrier_162_jpg.rf.a9e0afa47c063261d566e45058074f01.txt
#  extracting: train/american_pit_bull_terrier_163_jpg.rf.073fd906ee9552198570f44985d80557.jpg
#  extracting: train/american_pit_bull_terrier_163_jpg.rf.073fd906ee9552198570f44985d80557.txt
#  extracting: train/american_pit_bull_terrier_165_jpg.rf.7d8b301957566b02ef18d510d95bda66.jpg
#  extracting: train/american_pit_bull_terrier_165_jpg.rf.7d8b301957566b02ef18d510d95bda66.txt
#  extracting: train/american_pit_bull_terrier_166_jpg.rf.6bf5f3af75b821bbd01c01909c6ecc6b.jpg
#  extracting: train/american_pit_bull_terrier_166_jpg.rf.6bf5f3af75b821bbd01c01909c6ecc6b.txt
#  extracting: train/american_pit_bull_terrier_167_jpg.rf.5a7157a07da5be3db6e277dea94ba5cb.jpg
#  extracting: train/american_pit_bull_terrier_167_jpg.rf.5a7157a07da5be3db6e277dea94ba5cb.txt
#  extracting: train/american_pit_bull_terrier_168_jpg.rf.ab613e9026fa1f7a49ece3ba89a68111.jpg
#  extracting: train/american_pit_bull_terrier_168_jpg.rf.ab613e9026fa1f7a49ece3ba89a68111.txt
#  extracting: train/american_pit_bull_terrier_169_jpg.rf.9f188df8b389b34b18faea1776a20b6e.jpg
#  extracting: train/american_pit_bull_terrier_169_jpg.rf.9f188df8b389b34b18faea1776a20b6e.txt
#  extracting: train/american_pit_bull_terrier_16_jpg.rf.7baaa52a4c7daa6bacaa96edf76433e8.jpg
#  extracting: train/american_pit_bull_terrier_16_jpg.rf.7baaa52a4c7daa6bacaa96edf76433e8.txt
#  extracting: train/american_pit_bull_terrier_170_jpg.rf.ac8de4a00f39cac621d05a837b7c9035.jpg
#  extracting: train/american_pit_bull_terrier_170_jpg.rf.ac8de4a00f39cac621d05a837b7c9035.txt
#  extracting: train/american_pit_bull_terrier_171_jpg.rf.97a68212399a8d0d5a84958fa599f4c1.jpg
#  extracting: train/american_pit_bull_terrier_171_jpg.rf.97a68212399a8d0d5a84958fa599f4c1.txt
#  extracting: train/american_pit_bull_terrier_172_jpg.rf.8aa1847ca1c204580a220235f1d7de1d.jpg
#  extracting: train/american_pit_bull_terrier_172_jpg.rf.8aa1847ca1c204580a220235f1d7de1d.txt
#  extracting: train/american_pit_bull_terrier_173_jpg.rf.2d8dd4861f1fd1e3a7e6fecdd1484753.jpg
#  extracting: train/american_pit_bull_terrier_173_jpg.rf.2d8dd4861f1fd1e3a7e6fecdd1484753.txt
#  extracting: train/american_pit_bull_terrier_174_jpg.rf.f816679e631e482b0563eafb80623c7e.jpg
#  extracting: train/american_pit_bull_terrier_174_jpg.rf.f816679e631e482b0563eafb80623c7e.txt
#  extracting: train/american_pit_bull_terrier_175_jpg.rf.f9d9a6a3ad01486a217e77531f44d6f3.jpg
#  extracting: train/american_pit_bull_terrier_175_jpg.rf.f9d9a6a3ad01486a217e77531f44d6f3.txt
#  extracting: train/american_pit_bull_terrier_176_jpg.rf.deaf61189893b20d7a4c1032a6f63077.jpg
#  extracting: train/american_pit_bull_terrier_176_jpg.rf.deaf61189893b20d7a4c1032a6f63077.txt
#  extracting: train/american_pit_bull_terrier_177_jpg.rf.eb8c0b039fdfa81e2037a3612b4271f8.jpg
#  extracting: train/american_pit_bull_terrier_177_jpg.rf.eb8c0b039fdfa81e2037a3612b4271f8.txt
#  extracting: train/american_pit_bull_terrier_178_jpg.rf.4c83e633f0de55d3528c2d30e7a80a07.jpg
#  extracting: train/american_pit_bull_terrier_178_jpg.rf.4c83e633f0de55d3528c2d30e7a80a07.txt
#  extracting: train/american_pit_bull_terrier_179_jpg.rf.96c0045e8bbc7970e7e05debb368e8e4.jpg
#  extracting: train/american_pit_bull_terrier_179_jpg.rf.96c0045e8bbc7970e7e05debb368e8e4.txt
#  extracting: train/american_pit_bull_terrier_17_jpg.rf.807aba6733076bc6fd3b5e184ad2497a.jpg
#  extracting: train/american_pit_bull_terrier_17_jpg.rf.807aba6733076bc6fd3b5e184ad2497a.txt
#  extracting: train/american_pit_bull_terrier_180_jpg.rf.ee1ea3e8f53e5f9622aa686e8a3b5ca9.jpg
#  extracting: train/american_pit_bull_terrier_180_jpg.rf.ee1ea3e8f53e5f9622aa686e8a3b5ca9.txt
#  extracting: train/american_pit_bull_terrier_181_jpg.rf.ec938e084f49f945aea62dffb73c6325.jpg
#  extracting: train/american_pit_bull_terrier_181_jpg.rf.ec938e084f49f945aea62dffb73c6325.txt
#  extracting: train/american_pit_bull_terrier_183_jpg.rf.b75bba9407329298437a5daea37fb6dc.jpg
#  extracting: train/american_pit_bull_terrier_183_jpg.rf.b75bba9407329298437a5daea37fb6dc.txt
#  extracting: train/american_pit_bull_terrier_184_jpg.rf.896bd2ea67251c9f0f78ddc897de3529.jpg
#  extracting: train/american_pit_bull_terrier_184_jpg.rf.896bd2ea67251c9f0f78ddc897de3529.txt
#  extracting: train/american_pit_bull_terrier_185_jpg.rf.a7ca6326d14aa86aa4ff6ae534835159.jpg
#  extracting: train/american_pit_bull_terrier_185_jpg.rf.a7ca6326d14aa86aa4ff6ae534835159.txt
#  extracting: train/american_pit_bull_terrier_186_jpg.rf.ab8670a855a3c106025b1851f75dab47.jpg
#  extracting: train/american_pit_bull_terrier_186_jpg.rf.ab8670a855a3c106025b1851f75dab47.txt
#  extracting: train/american_pit_bull_terrier_188_jpg.rf.6a8eeca87574076f2878a4c878ad4f91.jpg
#  extracting: train/american_pit_bull_terrier_188_jpg.rf.6a8eeca87574076f2878a4c878ad4f91.txt
#  extracting: train/american_pit_bull_terrier_189_jpg.rf.05a6e1130f5bade2b14ae64d323dcc1d.jpg
#  extracting: train/american_pit_bull_terrier_189_jpg.rf.05a6e1130f5bade2b14ae64d323dcc1d.txt
#  extracting: train/american_pit_bull_terrier_18_jpg.rf.073a2b707b9d42f035fa4200b0cb96fa.jpg
#  extracting: train/american_pit_bull_terrier_18_jpg.rf.073a2b707b9d42f035fa4200b0cb96fa.txt
#  extracting: train/basset_hound_100_jpg.rf.d4319ba271749ac98fb5bba7dc44bc71.jpg
#  extracting: train/basset_hound_100_jpg.rf.d4319ba271749ac98fb5bba7dc44bc71.txt
#  extracting: train/basset_hound_101_jpg.rf.23a071dbc288e8b4862dbdf8dff10332.jpg
#  extracting: train/basset_hound_101_jpg.rf.23a071dbc288e8b4862dbdf8dff10332.txt
#  extracting: train/basset_hound_103_jpg.rf.e48fc631887c249498ac2a03a9e46cd8.jpg
#  extracting: train/basset_hound_103_jpg.rf.e48fc631887c249498ac2a03a9e46cd8.txt
#  extracting: train/basset_hound_104_jpg.rf.e25e5f428e86bba5d678a86544fc2b76.jpg
#  extracting: train/basset_hound_104_jpg.rf.e25e5f428e86bba5d678a86544fc2b76.txt
#  extracting: train/basset_hound_107_jpg.rf.d52e0c0c696427e0256e946f47529fe9.jpg
#  extracting: train/basset_hound_107_jpg.rf.d52e0c0c696427e0256e946f47529fe9.txt
#  extracting: train/basset_hound_108_jpg.rf.24827989d7c8288441980a557c64e477.jpg
#  extracting: train/basset_hound_108_jpg.rf.24827989d7c8288441980a557c64e477.txt
#  extracting: train/basset_hound_10_jpg.rf.ef6abeb9f86425822bf36ec48e02ba74.jpg
#  extracting: train/basset_hound_10_jpg.rf.ef6abeb9f86425822bf36ec48e02ba74.txt
#  extracting: train/basset_hound_110_jpg.rf.9d514169bcd531665b7fb3e7e1ed2e66.jpg
#  extracting: train/basset_hound_110_jpg.rf.9d514169bcd531665b7fb3e7e1ed2e66.txt
#  extracting: train/basset_hound_111_jpg.rf.b8ac48c908f720c825b3c5269d3805e8.jpg
#  extracting: train/basset_hound_111_jpg.rf.b8ac48c908f720c825b3c5269d3805e8.txt
#  extracting: train/basset_hound_112_jpg.rf.1d6e1ccb6706744d611354dead7c86c6.jpg
#  extracting: train/basset_hound_112_jpg.rf.1d6e1ccb6706744d611354dead7c86c6.txt
#  extracting: train/basset_hound_114_jpg.rf.1cf81d507a76e3705693e4951711658e.jpg
#  extracting: train/basset_hound_114_jpg.rf.1cf81d507a76e3705693e4951711658e.txt
#  extracting: train/basset_hound_116_jpg.rf.f4c2265491b16955085aa888450a33b9.jpg
#  extracting: train/basset_hound_116_jpg.rf.f4c2265491b16955085aa888450a33b9.txt
#  extracting: train/basset_hound_118_jpg.rf.bd9a66d77338139f0938ad4e22624cb0.jpg
#  extracting: train/basset_hound_118_jpg.rf.bd9a66d77338139f0938ad4e22624cb0.txt
#  extracting: train/basset_hound_119_jpg.rf.96bf204546b0dcecc6f05aa1e238e713.jpg
#  extracting: train/basset_hound_119_jpg.rf.96bf204546b0dcecc6f05aa1e238e713.txt
#  extracting: train/basset_hound_11_jpg.rf.860a22833e42145bf515c34bbc9ab12b.jpg
#  extracting: train/basset_hound_11_jpg.rf.860a22833e42145bf515c34bbc9ab12b.txt
#  extracting: train/basset_hound_120_jpg.rf.1f54a29d54743b6f17306fe7a51c6e5f.jpg
#  extracting: train/basset_hound_120_jpg.rf.1f54a29d54743b6f17306fe7a51c6e5f.txt
#  extracting: train/basset_hound_122_jpg.rf.1c9c95a34652c6c88039d1c68eadaa30.jpg
#  extracting: train/basset_hound_122_jpg.rf.1c9c95a34652c6c88039d1c68eadaa30.txt
#  extracting: train/basset_hound_123_jpg.rf.ea7a807693f28628b2e6ed5826085392.jpg
#  extracting: train/basset_hound_123_jpg.rf.ea7a807693f28628b2e6ed5826085392.txt
#  extracting: train/basset_hound_124_jpg.rf.21aa72bd47340d5abf23908521e69775.jpg
#  extracting: train/basset_hound_124_jpg.rf.21aa72bd47340d5abf23908521e69775.txt
#  extracting: train/basset_hound_125_jpg.rf.311b2a03256753a3030356364b561596.jpg
#  extracting: train/basset_hound_125_jpg.rf.311b2a03256753a3030356364b561596.txt
#  extracting: train/basset_hound_126_jpg.rf.36df644821bf76311f4b6915fac86e9f.jpg
#  extracting: train/basset_hound_126_jpg.rf.36df644821bf76311f4b6915fac86e9f.txt
#  extracting: train/basset_hound_12_jpg.rf.d78dc8c5fbd8151cc72b5ecff1c417a5.jpg
#  extracting: train/basset_hound_12_jpg.rf.d78dc8c5fbd8151cc72b5ecff1c417a5.txt
#  extracting: train/basset_hound_130_jpg.rf.8bc78e85c37e157881f9a05e6441fdde.jpg
#  extracting: train/basset_hound_130_jpg.rf.8bc78e85c37e157881f9a05e6441fdde.txt
#  extracting: train/basset_hound_132_jpg.rf.f83c2398f9ade484197af6417b1757b6.jpg
#  extracting: train/basset_hound_132_jpg.rf.f83c2398f9ade484197af6417b1757b6.txt
#  extracting: train/basset_hound_133_jpg.rf.541e4cca84be2c657620d2a5128e6d3f.jpg
#  extracting: train/basset_hound_133_jpg.rf.541e4cca84be2c657620d2a5128e6d3f.txt
#  extracting: train/basset_hound_135_jpg.rf.e689f7cf7bde9f718209d453156703ff.jpg
#  extracting: train/basset_hound_135_jpg.rf.e689f7cf7bde9f718209d453156703ff.txt
#  extracting: train/basset_hound_136_jpg.rf.9efb75fefdee542b892433e60efce1ba.jpg
#  extracting: train/basset_hound_136_jpg.rf.9efb75fefdee542b892433e60efce1ba.txt
#  extracting: train/basset_hound_137_jpg.rf.188993b821ada7d4a9847c55ab9d8212.jpg
#  extracting: train/basset_hound_137_jpg.rf.188993b821ada7d4a9847c55ab9d8212.txt
#  extracting: train/basset_hound_138_jpg.rf.40952c98c9a876518aca22b20a4f0b75.jpg
#  extracting: train/basset_hound_138_jpg.rf.40952c98c9a876518aca22b20a4f0b75.txt
#  extracting: train/basset_hound_139_jpg.rf.7cab4d184f0c9729e656d0618835c609.jpg
#  extracting: train/basset_hound_139_jpg.rf.7cab4d184f0c9729e656d0618835c609.txt
#  extracting: train/basset_hound_140_jpg.rf.b9459f6b50cad3dedf3fad5d3d972cfe.jpg
#  extracting: train/basset_hound_140_jpg.rf.b9459f6b50cad3dedf3fad5d3d972cfe.txt
#  extracting: train/basset_hound_141_jpg.rf.8bcbda5caf4630bb300e8271c2c7331a.jpg
#  extracting: train/basset_hound_141_jpg.rf.8bcbda5caf4630bb300e8271c2c7331a.txt
#  extracting: train/basset_hound_142_jpg.rf.7391f20a46b63851cccd26abb567a388.jpg
#  extracting: train/basset_hound_142_jpg.rf.7391f20a46b63851cccd26abb567a388.txt
#  extracting: train/basset_hound_144_jpg.rf.e4cc3553507e24dc8d4bbbfb7a19520a.jpg
#  extracting: train/basset_hound_144_jpg.rf.e4cc3553507e24dc8d4bbbfb7a19520a.txt
#  extracting: train/basset_hound_145_jpg.rf.6f534aac5a56fd5e8274aa2d9e002b69.jpg
#  extracting: train/basset_hound_145_jpg.rf.6f534aac5a56fd5e8274aa2d9e002b69.txt
#  extracting: train/basset_hound_146_jpg.rf.e1e75cb787d658be183436b6bf513bd5.jpg
#  extracting: train/basset_hound_146_jpg.rf.e1e75cb787d658be183436b6bf513bd5.txt
#  extracting: train/basset_hound_147_jpg.rf.f336e3987ba51d6c4366933aeb232ad1.jpg
#  extracting: train/basset_hound_147_jpg.rf.f336e3987ba51d6c4366933aeb232ad1.txt
#  extracting: train/basset_hound_148_jpg.rf.a649dddf4a74d5cc438f34fa584a6890.jpg
#  extracting: train/basset_hound_148_jpg.rf.a649dddf4a74d5cc438f34fa584a6890.txt
#  extracting: train/basset_hound_149_jpg.rf.147647842bef18f931f134e809592105.jpg
#  extracting: train/basset_hound_149_jpg.rf.147647842bef18f931f134e809592105.txt
#  extracting: train/basset_hound_151_jpg.rf.9a34d0f81afb2e23a70570e6142194cb.jpg
#  extracting: train/basset_hound_151_jpg.rf.9a34d0f81afb2e23a70570e6142194cb.txt
#  extracting: train/basset_hound_152_jpg.rf.1aa097f4490a7031a52ba19c36abf62d.jpg
#  extracting: train/basset_hound_152_jpg.rf.1aa097f4490a7031a52ba19c36abf62d.txt
#  extracting: train/basset_hound_153_jpg.rf.87eb8067d5db6586f7c11b4944b6aa79.jpg
#  extracting: train/basset_hound_153_jpg.rf.87eb8067d5db6586f7c11b4944b6aa79.txt
#  extracting: train/basset_hound_154_jpg.rf.303bda1818f462392f57361fab937009.jpg
#  extracting: train/basset_hound_154_jpg.rf.303bda1818f462392f57361fab937009.txt
#  extracting: train/basset_hound_155_jpg.rf.9f388fa6fff91ae81cd9c5bd93445cd7.jpg
#  extracting: train/basset_hound_155_jpg.rf.9f388fa6fff91ae81cd9c5bd93445cd7.txt
#  extracting: train/basset_hound_157_jpg.rf.7839081039581498e7ba96fe6d596276.jpg
#  extracting: train/basset_hound_157_jpg.rf.7839081039581498e7ba96fe6d596276.txt
#  extracting: train/basset_hound_158_jpg.rf.688f31ea63d0950c5b3adeaffbf76410.jpg
#  extracting: train/basset_hound_158_jpg.rf.688f31ea63d0950c5b3adeaffbf76410.txt
#  extracting: train/basset_hound_159_jpg.rf.90d61ab3a6a6b1908fbf6530673aef77.jpg
#  extracting: train/basset_hound_159_jpg.rf.90d61ab3a6a6b1908fbf6530673aef77.txt
#  extracting: train/basset_hound_15_jpg.rf.688c6c9bfc0c2536c8f1181d8f07d299.jpg
#  extracting: train/basset_hound_15_jpg.rf.688c6c9bfc0c2536c8f1181d8f07d299.txt
#  extracting: train/basset_hound_161_jpg.rf.bdb401484c2e0a67cbc85d59238abfe2.jpg
#  extracting: train/basset_hound_161_jpg.rf.bdb401484c2e0a67cbc85d59238abfe2.txt
#  extracting: train/basset_hound_164_jpg.rf.05656a3cde91a877506d628a6fb21433.jpg
#  extracting: train/basset_hound_164_jpg.rf.05656a3cde91a877506d628a6fb21433.txt
#  extracting: train/basset_hound_165_jpg.rf.8cf1938ee53b53089d7f1305b972013e.jpg
#  extracting: train/basset_hound_165_jpg.rf.8cf1938ee53b53089d7f1305b972013e.txt
#  extracting: train/basset_hound_168_jpg.rf.fa85173fe2aa8e6d412d34c3ba45144f.jpg
#  extracting: train/basset_hound_168_jpg.rf.fa85173fe2aa8e6d412d34c3ba45144f.txt
#  extracting: train/basset_hound_169_jpg.rf.f2576ac46cfaebb8225a0c74dcead795.jpg
#  extracting: train/basset_hound_169_jpg.rf.f2576ac46cfaebb8225a0c74dcead795.txt
#  extracting: train/basset_hound_16_jpg.rf.11a99eca77b68d819003743391ecf372.jpg
#  extracting: train/basset_hound_16_jpg.rf.11a99eca77b68d819003743391ecf372.txt
#  extracting: train/basset_hound_170_jpg.rf.e00f3f02baf15327fa0f1f9ec0cffe59.jpg
#  extracting: train/basset_hound_170_jpg.rf.e00f3f02baf15327fa0f1f9ec0cffe59.txt
#  extracting: train/basset_hound_171_jpg.rf.6bd9e4e015ee34d8228f69132d17be50.jpg
#  extracting: train/basset_hound_171_jpg.rf.6bd9e4e015ee34d8228f69132d17be50.txt
#  extracting: train/basset_hound_173_jpg.rf.0a5730fd572ac5e68015664e4f8990a9.jpg
#  extracting: train/basset_hound_173_jpg.rf.0a5730fd572ac5e68015664e4f8990a9.txt
#  extracting: train/basset_hound_174_jpg.rf.a0b17ce9609cfe384f6a250e4fbf6d35.jpg
#  extracting: train/basset_hound_174_jpg.rf.a0b17ce9609cfe384f6a250e4fbf6d35.txt
#  extracting: train/basset_hound_175_jpg.rf.146c0937decfa1f760b02266c3ce8416.jpg
#  extracting: train/basset_hound_175_jpg.rf.146c0937decfa1f760b02266c3ce8416.txt
#  extracting: train/basset_hound_176_jpg.rf.c2ead78081e6d656d9800cc205cce537.jpg
#  extracting: train/basset_hound_176_jpg.rf.c2ead78081e6d656d9800cc205cce537.txt
#  extracting: train/basset_hound_177_jpg.rf.155ae91c38b6e649f71d8d7d2acd78a5.jpg
#  extracting: train/basset_hound_177_jpg.rf.155ae91c38b6e649f71d8d7d2acd78a5.txt
#  extracting: train/basset_hound_178_jpg.rf.e324368785ff05a03f54626348bd6c78.jpg
#  extracting: train/basset_hound_178_jpg.rf.e324368785ff05a03f54626348bd6c78.txt
#  extracting: train/basset_hound_179_jpg.rf.023d9e883108f9b7faf12759dd8fadf8.jpg
#  extracting: train/basset_hound_179_jpg.rf.023d9e883108f9b7faf12759dd8fadf8.txt
#  extracting: train/basset_hound_181_jpg.rf.c14a75484828678aa26631cc04a86f3d.jpg
#  extracting: train/basset_hound_181_jpg.rf.c14a75484828678aa26631cc04a86f3d.txt
#  extracting: train/basset_hound_185_jpg.rf.8a93186328af47c27bfb94d427902a86.jpg
#  extracting: train/basset_hound_185_jpg.rf.8a93186328af47c27bfb94d427902a86.txt
#  extracting: train/basset_hound_186_jpg.rf.5dbeffdeb26c42818ba0162ce01fb04d.jpg
#  extracting: train/basset_hound_186_jpg.rf.5dbeffdeb26c42818ba0162ce01fb04d.txt
#  extracting: train/basset_hound_187_jpg.rf.63a5eb6e8c6d786a37666112a4a0336f.jpg
#  extracting: train/basset_hound_187_jpg.rf.63a5eb6e8c6d786a37666112a4a0336f.txt
#  extracting: train/basset_hound_189_jpg.rf.042afa1e340041a993493153ba6728f3.jpg
#  extracting: train/basset_hound_189_jpg.rf.042afa1e340041a993493153ba6728f3.txt
#  extracting: train/basset_hound_18_jpg.rf.30f359c7d175fd0a328726c698660a50.jpg
#  extracting: train/basset_hound_18_jpg.rf.30f359c7d175fd0a328726c698660a50.txt
#  extracting: train/beagle_100_jpg.rf.69bed2f7c113f308d6e8030696ec8d5a.jpg
#  extracting: train/beagle_100_jpg.rf.69bed2f7c113f308d6e8030696ec8d5a.txt
#  extracting: train/beagle_102_jpg.rf.e2fd3f041034454d75ad299f1b14974f.jpg
#  extracting: train/beagle_102_jpg.rf.e2fd3f041034454d75ad299f1b14974f.txt
#  extracting: train/beagle_104_jpg.rf.c528ee429d6e5f84191705c516de8e4f.jpg
#  extracting: train/beagle_104_jpg.rf.c528ee429d6e5f84191705c516de8e4f.txt
#  extracting: train/beagle_105_jpg.rf.3a98e1ebea95db3452ce19982624f7b1.jpg
#  extracting: train/beagle_105_jpg.rf.3a98e1ebea95db3452ce19982624f7b1.txt
#  extracting: train/beagle_108_jpg.rf.38582d7aee8f7bca4f67bafb1cfa5f9c.jpg
#  extracting: train/beagle_108_jpg.rf.38582d7aee8f7bca4f67bafb1cfa5f9c.txt
#  extracting: train/beagle_109_jpg.rf.88d0cd1f9b22f78182466c0c388e4359.jpg
#  extracting: train/beagle_109_jpg.rf.88d0cd1f9b22f78182466c0c388e4359.txt
#  extracting: train/beagle_113_jpg.rf.d07be6c3253b91e4f67a3eb032a3ced2.jpg
#  extracting: train/beagle_113_jpg.rf.d07be6c3253b91e4f67a3eb032a3ced2.txt
#  extracting: train/beagle_114_jpg.rf.739f4491798aada37544e51d3c572b89.jpg
#  extracting: train/beagle_114_jpg.rf.739f4491798aada37544e51d3c572b89.txt
#  extracting: train/beagle_115_jpg.rf.c37cde8c8ca27410f99ab3a174817f30.jpg
#  extracting: train/beagle_115_jpg.rf.c37cde8c8ca27410f99ab3a174817f30.txt
#  extracting: train/beagle_117_jpg.rf.1b5bfc0bd928a74623846e9f133a857f.jpg
#  extracting: train/beagle_117_jpg.rf.1b5bfc0bd928a74623846e9f133a857f.txt
#  extracting: train/beagle_118_jpg.rf.8b31326cc6ef656fe10d993fa71abe93.jpg
#  extracting: train/beagle_118_jpg.rf.8b31326cc6ef656fe10d993fa71abe93.txt
#  extracting: train/beagle_120_jpg.rf.244542803d27bdecdca62c41b2f068fb.jpg
#  extracting: train/beagle_120_jpg.rf.244542803d27bdecdca62c41b2f068fb.txt
#  extracting: train/beagle_121_jpg.rf.ab6c428dfb7ac45bbc96c38451b72bf4.jpg
#  extracting: train/beagle_121_jpg.rf.ab6c428dfb7ac45bbc96c38451b72bf4.txt
#  extracting: train/beagle_122_jpg.rf.4911f477f9a3948129cdeef7ff54923c.jpg
#  extracting: train/beagle_122_jpg.rf.4911f477f9a3948129cdeef7ff54923c.txt
#  extracting: train/beagle_123_jpg.rf.1f8a143cec7d54032e3acc90de486c12.jpg
#  extracting: train/beagle_123_jpg.rf.1f8a143cec7d54032e3acc90de486c12.txt
#  extracting: train/beagle_124_jpg.rf.c4f109002f30e886f465a68657d724ba.jpg
#  extracting: train/beagle_124_jpg.rf.c4f109002f30e886f465a68657d724ba.txt
#  extracting: train/beagle_125_jpg.rf.6054d1cfca767c51bd3f62a568b65037.jpg
#  extracting: train/beagle_125_jpg.rf.6054d1cfca767c51bd3f62a568b65037.txt
#  extracting: train/beagle_126_jpg.rf.9b97e68016b85be437278e98377c1cd7.jpg
#  extracting: train/beagle_126_jpg.rf.9b97e68016b85be437278e98377c1cd7.txt
#  extracting: train/beagle_127_jpg.rf.736fd5a57facd0b9fc50949bf85049f0.jpg
#  extracting: train/beagle_127_jpg.rf.736fd5a57facd0b9fc50949bf85049f0.txt
#  extracting: train/beagle_129_jpg.rf.1ef3aaaad8e596f113d204b11641a616.jpg
#  extracting: train/beagle_129_jpg.rf.1ef3aaaad8e596f113d204b11641a616.txt
#  extracting: train/beagle_12_jpg.rf.68d7f6172a740fc5112597e48af33658.jpg
#  extracting: train/beagle_12_jpg.rf.68d7f6172a740fc5112597e48af33658.txt
#  extracting: train/beagle_130_jpg.rf.02a5a6d28a2ecbe3b31d5c9a06f040ec.jpg
#  extracting: train/beagle_130_jpg.rf.02a5a6d28a2ecbe3b31d5c9a06f040ec.txt
#  extracting: train/beagle_131_jpg.rf.d602f8a23cd1256da4cdd68c454c12fb.jpg
#  extracting: train/beagle_131_jpg.rf.d602f8a23cd1256da4cdd68c454c12fb.txt
#  extracting: train/beagle_135_jpg.rf.1a7b144036a0724cee3837a0b337db06.jpg
#  extracting: train/beagle_135_jpg.rf.1a7b144036a0724cee3837a0b337db06.txt
#  extracting: train/beagle_138_jpg.rf.0138bb7fce1e364bb60d9e0d08f2506c.jpg
#  extracting: train/beagle_138_jpg.rf.0138bb7fce1e364bb60d9e0d08f2506c.txt
#  extracting: train/beagle_13_jpg.rf.0df09c37660479a06da358c21d929914.jpg
#  extracting: train/beagle_13_jpg.rf.0df09c37660479a06da358c21d929914.txt
#  extracting: train/beagle_140_jpg.rf.9c34dc5c474f6b7679c3782e2520e1bc.jpg
#  extracting: train/beagle_140_jpg.rf.9c34dc5c474f6b7679c3782e2520e1bc.txt
#  extracting: train/beagle_141_jpg.rf.2a2dc50e676961996c714b90acf65fcd.jpg
#  extracting: train/beagle_141_jpg.rf.2a2dc50e676961996c714b90acf65fcd.txt
#  extracting: train/beagle_142_jpg.rf.5119f870f6781c75cf8b59d914bf17ff.jpg
#  extracting: train/beagle_142_jpg.rf.5119f870f6781c75cf8b59d914bf17ff.txt
#  extracting: train/beagle_143_jpg.rf.5c6f8ac7a4825e3808ad267e9c122ebb.jpg
#  extracting: train/beagle_143_jpg.rf.5c6f8ac7a4825e3808ad267e9c122ebb.txt
#  extracting: train/beagle_144_jpg.rf.36e265d6834bfc76543b7bc482fe1c37.jpg
#  extracting: train/beagle_144_jpg.rf.36e265d6834bfc76543b7bc482fe1c37.txt
#  extracting: train/beagle_145_jpg.rf.cedcc9392769a8e93a1af65c0dd185fe.jpg
#  extracting: train/beagle_145_jpg.rf.cedcc9392769a8e93a1af65c0dd185fe.txt
#  extracting: train/beagle_147_jpg.rf.ca306a59a4d56895624c2b2bfde47a1a.jpg
#  extracting: train/beagle_147_jpg.rf.ca306a59a4d56895624c2b2bfde47a1a.txt
#  extracting: train/beagle_149_jpg.rf.8657a664408ea31e8b8c8ba4aa3c19f4.jpg
#  extracting: train/beagle_149_jpg.rf.8657a664408ea31e8b8c8ba4aa3c19f4.txt
#  extracting: train/beagle_14_jpg.rf.e6291d1540895e362b6ad72c8493dda0.jpg
#  extracting: train/beagle_14_jpg.rf.e6291d1540895e362b6ad72c8493dda0.txt
#  extracting: train/beagle_150_jpg.rf.d225ad4f0cf8051be86f21533eef7094.jpg
#  extracting: train/beagle_150_jpg.rf.d225ad4f0cf8051be86f21533eef7094.txt
#  extracting: train/beagle_151_jpg.rf.4e6f36bea17f9880981e9a400b36b417.jpg
#  extracting: train/beagle_151_jpg.rf.4e6f36bea17f9880981e9a400b36b417.txt
#  extracting: train/beagle_152_jpg.rf.278f5b4e4512046c7582cde17b799b86.jpg
#  extracting: train/beagle_152_jpg.rf.278f5b4e4512046c7582cde17b799b86.txt
#  extracting: train/beagle_154_jpg.rf.b7712e5db4a238ae4eb5994f1df1c524.jpg
#  extracting: train/beagle_154_jpg.rf.b7712e5db4a238ae4eb5994f1df1c524.txt
#  extracting: train/beagle_155_jpg.rf.bc752f1726a12bd1ed53dc16675a2709.jpg
#  extracting: train/beagle_155_jpg.rf.bc752f1726a12bd1ed53dc16675a2709.txt
#  extracting: train/beagle_156_jpg.rf.16b0738fa77ea8740fa7806104a693cc.jpg
#  extracting: train/beagle_156_jpg.rf.16b0738fa77ea8740fa7806104a693cc.txt
#  extracting: train/beagle_157_jpg.rf.0592bec3f1c43fcbe71b8f37dc0d78dd.jpg
#  extracting: train/beagle_157_jpg.rf.0592bec3f1c43fcbe71b8f37dc0d78dd.txt
#  extracting: train/beagle_160_jpg.rf.270d4e442f5175ba8991c8ab87e28e4a.jpg
#  extracting: train/beagle_160_jpg.rf.270d4e442f5175ba8991c8ab87e28e4a.txt
#  extracting: train/beagle_162_jpg.rf.912ef27b0875e05b59c8c0f09e0232f3.jpg
#  extracting: train/beagle_162_jpg.rf.912ef27b0875e05b59c8c0f09e0232f3.txt
#  extracting: train/beagle_163_jpg.rf.161d343c282c9e1a3be0518e06898e7a.jpg
#  extracting: train/beagle_163_jpg.rf.161d343c282c9e1a3be0518e06898e7a.txt
#  extracting: train/beagle_164_jpg.rf.175c8a126716326335d1d6431c7564f3.jpg
#  extracting: train/beagle_164_jpg.rf.175c8a126716326335d1d6431c7564f3.txt
#  extracting: train/beagle_165_jpg.rf.400f5629fffcb12f5b7eeec070b1c857.jpg
#  extracting: train/beagle_165_jpg.rf.400f5629fffcb12f5b7eeec070b1c857.txt
#  extracting: train/beagle_166_jpg.rf.8dcd0a103e838c8efc49d467d2a060b8.jpg
#  extracting: train/beagle_166_jpg.rf.8dcd0a103e838c8efc49d467d2a060b8.txt
#  extracting: train/beagle_167_jpg.rf.b274f72f0fa3b271206a9897458d8cb8.jpg
#  extracting: train/beagle_167_jpg.rf.b274f72f0fa3b271206a9897458d8cb8.txt
#  extracting: train/beagle_168_jpg.rf.7f812185f46463f725c54bc211dd490d.jpg
#  extracting: train/beagle_168_jpg.rf.7f812185f46463f725c54bc211dd490d.txt
#  extracting: train/beagle_169_jpg.rf.86f5d85a25e5253b91ab2544b74f63d4.jpg
#  extracting: train/beagle_169_jpg.rf.86f5d85a25e5253b91ab2544b74f63d4.txt
#  extracting: train/beagle_16_jpg.rf.e6c8f01a45e8145987b6e4be59ffc807.jpg
#  extracting: train/beagle_16_jpg.rf.e6c8f01a45e8145987b6e4be59ffc807.txt
#  extracting: train/beagle_170_jpg.rf.16268ed708c5177089dc7e829c109cf9.jpg
#  extracting: train/beagle_170_jpg.rf.16268ed708c5177089dc7e829c109cf9.txt
#  extracting: train/beagle_171_jpg.rf.bad9f33f0ed0a339fd3f5c78a4fbc79b.jpg
#  extracting: train/beagle_171_jpg.rf.bad9f33f0ed0a339fd3f5c78a4fbc79b.txt
#  extracting: train/beagle_172_jpg.rf.3887f32466f201ef004ec45c82efa22c.jpg
#  extracting: train/beagle_172_jpg.rf.3887f32466f201ef004ec45c82efa22c.txt
#  extracting: train/beagle_173_jpg.rf.e6ea6e838ba128b1f057b74c315eb897.jpg
#  extracting: train/beagle_173_jpg.rf.e6ea6e838ba128b1f057b74c315eb897.txt
#  extracting: train/beagle_174_jpg.rf.777af8a0d6af6c49fe893b1461e4e1ff.jpg
#  extracting: train/beagle_174_jpg.rf.777af8a0d6af6c49fe893b1461e4e1ff.txt
#  extracting: train/beagle_175_jpg.rf.87ed6b22ef07d39c167f12ed18d8ca94.jpg
#  extracting: train/beagle_175_jpg.rf.87ed6b22ef07d39c167f12ed18d8ca94.txt
#  extracting: train/beagle_176_jpg.rf.5c639d00cde4f223f0bba9dadb632849.jpg
#  extracting: train/beagle_176_jpg.rf.5c639d00cde4f223f0bba9dadb632849.txt
#  extracting: train/beagle_177_jpg.rf.20aca888526ab98cc60a90827e369066.jpg
#  extracting: train/beagle_177_jpg.rf.20aca888526ab98cc60a90827e369066.txt
#  extracting: train/beagle_178_jpg.rf.e73498cbe325db515e7f980ff130d862.jpg
#  extracting: train/beagle_178_jpg.rf.e73498cbe325db515e7f980ff130d862.txt
#  extracting: train/beagle_181_jpg.rf.7fc5b6bd144bb66f7bcfed107d1493dd.jpg
#  extracting: train/beagle_181_jpg.rf.7fc5b6bd144bb66f7bcfed107d1493dd.txt
#  extracting: train/beagle_182_jpg.rf.94e4a66f4495a122a55e8cf5cd4e16b6.jpg
#  extracting: train/beagle_182_jpg.rf.94e4a66f4495a122a55e8cf5cd4e16b6.txt
#  extracting: train/beagle_183_jpg.rf.94376f142242d5b8fba1f513d6381de8.jpg
#  extracting: train/beagle_183_jpg.rf.94376f142242d5b8fba1f513d6381de8.txt
#  extracting: train/beagle_184_jpg.rf.6baf6277470f6f07395178b4977bc5c1.jpg
#  extracting: train/beagle_184_jpg.rf.6baf6277470f6f07395178b4977bc5c1.txt
#  extracting: train/beagle_186_jpg.rf.b5762d09c94ae046fec29d77e55dfa67.jpg
#  extracting: train/beagle_186_jpg.rf.b5762d09c94ae046fec29d77e55dfa67.txt
#  extracting: train/beagle_187_jpg.rf.0435dbfb1ebc7d607d489a825d46ad87.jpg
#  extracting: train/beagle_187_jpg.rf.0435dbfb1ebc7d607d489a825d46ad87.txt
#  extracting: train/beagle_18_jpg.rf.f867b087320eddfc7fece24a5dda20db.jpg
#  extracting: train/beagle_18_jpg.rf.f867b087320eddfc7fece24a5dda20db.txt
#  extracting: train/beagle_190_jpg.rf.8356bc18ba4351c5e053e0b8ac057bc6.jpg
#  extracting: train/beagle_190_jpg.rf.8356bc18ba4351c5e053e0b8ac057bc6.txt
#  extracting: train/beagle_192_jpg.rf.fdaf8db7220c109ca4e785b915c0fae9.jpg
#  extracting: train/beagle_192_jpg.rf.fdaf8db7220c109ca4e785b915c0fae9.txt
#  extracting: train/beagle_193_jpg.rf.0e52f88e522692e1ab38908cfcc0c9fe.jpg
#  extracting: train/beagle_193_jpg.rf.0e52f88e522692e1ab38908cfcc0c9fe.txt
#  extracting: train/beagle_194_jpg.rf.6c9f42335024b21d394d7d2af8bdbd04.jpg
# ...
#  extracting: valid/scottish_terrier_159_jpg.rf.8a75d7b0d75e9300569968f9f24afa2e.txt
#  extracting: valid/scottish_terrier_163_jpg.rf.1ced2617f1dbeb117e9e50c480d4672e.jpg
#  extracting: valid/scottish_terrier_163_jpg.rf.1ced2617f1dbeb117e9e50c480d4672e.txt
#  extracting: valid/scottish_terrier_170_jpg.rf.69b14aa7172dd73c43170313ba1f931a.jpg
#  extracting: valid/scottish_terrier_170_jpg.rf.69b14aa7172dd73c43170313ba1f931a.txt
#  extracting: valid/scottish_terrier_173_jpg.rf.4a75604ea80cac7a475052f1eafde18d.jpg
#  extracting: valid/scottish_terrier_173_jpg.rf.4a75604ea80cac7a475052f1eafde18d.txt
#  extracting: valid/scottish_terrier_180_jpg.rf.145c5d66594acd47c45c52bdf79efa4b.jpg
#  extracting: valid/scottish_terrier_180_jpg.rf.145c5d66594acd47c45c52bdf79efa4b.txt
#  extracting: valid/scottish_terrier_187_jpg.rf.2b5e996fb3ff1698288c264537427b5a.jpg
#  extracting: valid/scottish_terrier_187_jpg.rf.2b5e996fb3ff1698288c264537427b5a.txt
#  extracting: valid/scottish_terrier_18_jpg.rf.0d3926a92b4ed38e0603e2dfb880f019.jpg
#  extracting: valid/scottish_terrier_18_jpg.rf.0d3926a92b4ed38e0603e2dfb880f019.txt
#  extracting: valid/shiba_inu_114_jpg.rf.85c7c831d388bb0e4b2facf0876a8f93.jpg
#  extracting: valid/shiba_inu_114_jpg.rf.85c7c831d388bb0e4b2facf0876a8f93.txt
#  extracting: valid/shiba_inu_116_jpg.rf.30a037d3bd5752f1c07ed4c572bca9f0.jpg
#  extracting: valid/shiba_inu_116_jpg.rf.30a037d3bd5752f1c07ed4c572bca9f0.txt
#  extracting: valid/shiba_inu_11_jpg.rf.f05765cc5a0d3a0d635d90d9cfa14697.jpg
#  extracting: valid/shiba_inu_11_jpg.rf.f05765cc5a0d3a0d635d90d9cfa14697.txt
#  extracting: valid/shiba_inu_127_jpg.rf.fce23bf424fe93be03083daed866930a.jpg
#  extracting: valid/shiba_inu_127_jpg.rf.fce23bf424fe93be03083daed866930a.txt
#  extracting: valid/shiba_inu_128_jpg.rf.1746815e3106949dd44b7e7268fa927a.jpg
#  extracting: valid/shiba_inu_128_jpg.rf.1746815e3106949dd44b7e7268fa927a.txt
#  extracting: valid/shiba_inu_129_jpg.rf.e2765716dd7dfa264cf7e04cdee6df32.jpg
#  extracting: valid/shiba_inu_129_jpg.rf.e2765716dd7dfa264cf7e04cdee6df32.txt
#  extracting: valid/shiba_inu_12_jpg.rf.dfa1fd3f7fd773df6e82361d6cf57cf6.jpg
#  extracting: valid/shiba_inu_12_jpg.rf.dfa1fd3f7fd773df6e82361d6cf57cf6.txt
#  extracting: valid/shiba_inu_133_jpg.rf.2db9b9b51bab6b3e0fdbd653e82b6f38.jpg
#  extracting: valid/shiba_inu_133_jpg.rf.2db9b9b51bab6b3e0fdbd653e82b6f38.txt
#  extracting: valid/shiba_inu_154_jpg.rf.c4ad9af190620fde97dcc1ad20226f47.jpg
#  extracting: valid/shiba_inu_154_jpg.rf.c4ad9af190620fde97dcc1ad20226f47.txt
#  extracting: valid/shiba_inu_162_jpg.rf.1643ad2274bd059ed59b738fbe715056.jpg
#  extracting: valid/shiba_inu_162_jpg.rf.1643ad2274bd059ed59b738fbe715056.txt
#  extracting: valid/shiba_inu_16_jpg.rf.4a836d5f6efc94a9a2a7762603eca8c8.jpg
#  extracting: valid/shiba_inu_16_jpg.rf.4a836d5f6efc94a9a2a7762603eca8c8.txt
#  extracting: valid/shiba_inu_174_jpg.rf.16187883e3f62cf2dbef3ba2f77c81c9.jpg
#  extracting: valid/shiba_inu_174_jpg.rf.16187883e3f62cf2dbef3ba2f77c81c9.txt
#  extracting: valid/shiba_inu_182_jpg.rf.fc4de4645476d51c9ca1e058ac9ae9f4.jpg
#  extracting: valid/shiba_inu_182_jpg.rf.fc4de4645476d51c9ca1e058ac9ae9f4.txt
#  extracting: valid/shiba_inu_190_jpg.rf.22dc8ed757f90fff29c0309c8bff254a.jpg
#  extracting: valid/shiba_inu_190_jpg.rf.22dc8ed757f90fff29c0309c8bff254a.txt
#  extracting: valid/shiba_inu_193_jpg.rf.b4eff0cf243a768e5d49a0811a009768.jpg
#  extracting: valid/shiba_inu_193_jpg.rf.b4eff0cf243a768e5d49a0811a009768.txt
#  extracting: valid/staffordshire_bull_terrier_100_jpg.rf.68b685608d3d6d0c8a69769d2d041ffe.jpg
#  extracting: valid/staffordshire_bull_terrier_100_jpg.rf.68b685608d3d6d0c8a69769d2d041ffe.txt
#  extracting: valid/staffordshire_bull_terrier_105_jpg.rf.87bfc10ab44e9900ef65224591f56a01.jpg
#  extracting: valid/staffordshire_bull_terrier_105_jpg.rf.87bfc10ab44e9900ef65224591f56a01.txt
#  extracting: valid/staffordshire_bull_terrier_107_jpg.rf.c9c4bcd3cfc41b800fd2ef61ff5e7346.jpg
#  extracting: valid/staffordshire_bull_terrier_107_jpg.rf.c9c4bcd3cfc41b800fd2ef61ff5e7346.txt
#  extracting: valid/staffordshire_bull_terrier_10_jpg.rf.05d0dfe2ab1855a83878fca677886193.jpg
#  extracting: valid/staffordshire_bull_terrier_10_jpg.rf.05d0dfe2ab1855a83878fca677886193.txt
#  extracting: valid/staffordshire_bull_terrier_111_jpg.rf.ed6078662863e7b18ebbd6f408fbd1a0.jpg
#  extracting: valid/staffordshire_bull_terrier_111_jpg.rf.ed6078662863e7b18ebbd6f408fbd1a0.txt
#  extracting: valid/staffordshire_bull_terrier_114_jpg.rf.6ab61802f5a5e586b735a470d712b83b.jpg
#  extracting: valid/staffordshire_bull_terrier_114_jpg.rf.6ab61802f5a5e586b735a470d712b83b.txt
#  extracting: valid/staffordshire_bull_terrier_115_jpg.rf.c538862644236eccca7b8db4b8069a75.jpg
#  extracting: valid/staffordshire_bull_terrier_115_jpg.rf.c538862644236eccca7b8db4b8069a75.txt
#  extracting: valid/staffordshire_bull_terrier_117_jpg.rf.c5da9c248ad7750502ac57b4490a6768.jpg
#  extracting: valid/staffordshire_bull_terrier_117_jpg.rf.c5da9c248ad7750502ac57b4490a6768.txt
#  extracting: valid/staffordshire_bull_terrier_11_jpg.rf.c1d36bc868f7adbb63b178887a97707b.jpg
#  extracting: valid/staffordshire_bull_terrier_11_jpg.rf.c1d36bc868f7adbb63b178887a97707b.txt
#  extracting: valid/staffordshire_bull_terrier_120_jpg.rf.19cf80f3b73cd096089ba55951c03016.jpg
#  extracting: valid/staffordshire_bull_terrier_120_jpg.rf.19cf80f3b73cd096089ba55951c03016.txt
#  extracting: valid/staffordshire_bull_terrier_125_jpg.rf.c679d8c520e01b959878b687125b1731.jpg
#  extracting: valid/staffordshire_bull_terrier_125_jpg.rf.c679d8c520e01b959878b687125b1731.txt
#  extracting: valid/staffordshire_bull_terrier_131_jpg.rf.a0f26d427bef6d605ee2282047b16692.jpg
#  extracting: valid/staffordshire_bull_terrier_131_jpg.rf.a0f26d427bef6d605ee2282047b16692.txt
#  extracting: valid/staffordshire_bull_terrier_133_jpg.rf.5142bb42300bc7699cc94b186ea4ce99.jpg
#  extracting: valid/staffordshire_bull_terrier_133_jpg.rf.5142bb42300bc7699cc94b186ea4ce99.txt
#  extracting: valid/staffordshire_bull_terrier_136_jpg.rf.537820b1b3a3d9feb8e9c55ad3260a4b.jpg
#  extracting: valid/staffordshire_bull_terrier_136_jpg.rf.537820b1b3a3d9feb8e9c55ad3260a4b.txt
#  extracting: valid/staffordshire_bull_terrier_139_jpg.rf.79b4bd31053cb81cb01fffd01bd0d5d4.jpg
#  extracting: valid/staffordshire_bull_terrier_139_jpg.rf.79b4bd31053cb81cb01fffd01bd0d5d4.txt
#  extracting: valid/staffordshire_bull_terrier_158_jpg.rf.4be90b451c7d40c5ab3d398ae973ac1b.jpg
#  extracting: valid/staffordshire_bull_terrier_158_jpg.rf.4be90b451c7d40c5ab3d398ae973ac1b.txt
#  extracting: valid/staffordshire_bull_terrier_163_jpg.rf.3d3f4175867c4371520d81bde183d725.jpg
#  extracting: valid/staffordshire_bull_terrier_163_jpg.rf.3d3f4175867c4371520d81bde183d725.txt
#  extracting: valid/staffordshire_bull_terrier_166_jpg.rf.b057416c76eda32f3ac481a461c006e2.jpg
#  extracting: valid/staffordshire_bull_terrier_166_jpg.rf.b057416c76eda32f3ac481a461c006e2.txt
#  extracting: valid/staffordshire_bull_terrier_170_jpg.rf.577e38eeafa666add50c4ca74bedc4fd.jpg
#  extracting: valid/staffordshire_bull_terrier_170_jpg.rf.577e38eeafa666add50c4ca74bedc4fd.txt
#  extracting: valid/staffordshire_bull_terrier_174_jpg.rf.d5e64ed6188462bd80db969bca4fbdab.jpg
#  extracting: valid/staffordshire_bull_terrier_174_jpg.rf.d5e64ed6188462bd80db969bca4fbdab.txt
#  extracting: valid/staffordshire_bull_terrier_176_jpg.rf.07120af5de5278f217a6604a6983e9c8.jpg
#  extracting: valid/staffordshire_bull_terrier_176_jpg.rf.07120af5de5278f217a6604a6983e9c8.txt
#  extracting: valid/staffordshire_bull_terrier_183_jpg.rf.46eca404b36d2c4c2d60ce80aa43a7e7.jpg
#  extracting: valid/staffordshire_bull_terrier_183_jpg.rf.46eca404b36d2c4c2d60ce80aa43a7e7.txt
#  extracting: valid/staffordshire_bull_terrier_199_jpg.rf.e271520c2359eb465abf041bf36c6b1b.jpg
#  extracting: valid/staffordshire_bull_terrier_199_jpg.rf.e271520c2359eb465abf041bf36c6b1b.txt
#  extracting: valid/wheaten_terrier_102_jpg.rf.1739e22a718b5795f24dfd8aa7040c1f.jpg
#  extracting: valid/wheaten_terrier_102_jpg.rf.1739e22a718b5795f24dfd8aa7040c1f.txt
#  extracting: valid/wheaten_terrier_106_jpg.rf.d6091d44c5a8d554590bb9a215e93fbf.jpg
#  extracting: valid/wheaten_terrier_106_jpg.rf.d6091d44c5a8d554590bb9a215e93fbf.txt
#  extracting: valid/wheaten_terrier_107_jpg.rf.61c7646f97511f441b946a21874e228d.jpg
#  extracting: valid/wheaten_terrier_107_jpg.rf.61c7646f97511f441b946a21874e228d.txt
#  extracting: valid/wheaten_terrier_109_jpg.rf.c6f6432d53f7423a3e8cb3d15a1284db.jpg
#  extracting: valid/wheaten_terrier_109_jpg.rf.c6f6432d53f7423a3e8cb3d15a1284db.txt
#  extracting: valid/wheaten_terrier_118_jpg.rf.f7eca33e76ae1204f437a9afbcf28094.jpg
#  extracting: valid/wheaten_terrier_118_jpg.rf.f7eca33e76ae1204f437a9afbcf28094.txt
#  extracting: valid/wheaten_terrier_123_jpg.rf.5c5e047cb948aa6b0a5baa37fd92f1e0.jpg
#  extracting: valid/wheaten_terrier_123_jpg.rf.5c5e047cb948aa6b0a5baa37fd92f1e0.txt
#  extracting: valid/wheaten_terrier_12_jpg.rf.7b80960b4c94644e1fe50c29373554ce.jpg
#  extracting: valid/wheaten_terrier_12_jpg.rf.7b80960b4c94644e1fe50c29373554ce.txt
#  extracting: valid/wheaten_terrier_130_jpg.rf.be4470078c5168bd8e38baf3b105d8e7.jpg
#  extracting: valid/wheaten_terrier_130_jpg.rf.be4470078c5168bd8e38baf3b105d8e7.txt
#  extracting: valid/wheaten_terrier_136_jpg.rf.0d79e4f7fb603abc0a0c08ad3bc17d7a.jpg
#  extracting: valid/wheaten_terrier_136_jpg.rf.0d79e4f7fb603abc0a0c08ad3bc17d7a.txt
#  extracting: valid/wheaten_terrier_151_jpg.rf.d0167014c0ca3934363bc49b75e9e270.jpg
#  extracting: valid/wheaten_terrier_151_jpg.rf.d0167014c0ca3934363bc49b75e9e270.txt
#  extracting: valid/wheaten_terrier_154_jpg.rf.338064f39e8a7e698532ef3548ed9388.jpg
#  extracting: valid/wheaten_terrier_154_jpg.rf.338064f39e8a7e698532ef3548ed9388.txt
#  extracting: valid/wheaten_terrier_164_jpg.rf.f4fe075d74b9357a4d65cec243849ff3.jpg
#  extracting: valid/wheaten_terrier_164_jpg.rf.f4fe075d74b9357a4d65cec243849ff3.txt
#  extracting: valid/wheaten_terrier_167_jpg.rf.48d644c1deca5222ee0813330f0272e3.jpg
#  extracting: valid/wheaten_terrier_167_jpg.rf.48d644c1deca5222ee0813330f0272e3.txt
#  extracting: valid/wheaten_terrier_168_jpg.rf.5acc559eace6b4ea1e47efe11fc46332.jpg
#  extracting: valid/wheaten_terrier_168_jpg.rf.5acc559eace6b4ea1e47efe11fc46332.txt
#  extracting: valid/wheaten_terrier_172_jpg.rf.c71bf678e5e587c978f41e3d4e1fae26.jpg
#  extracting: valid/wheaten_terrier_172_jpg.rf.c71bf678e5e587c978f41e3d4e1fae26.txt
#  extracting: valid/wheaten_terrier_174_jpg.rf.9a14d7174e9c41a220de71a5f2cc02b3.jpg
#  extracting: valid/wheaten_terrier_174_jpg.rf.9a14d7174e9c41a220de71a5f2cc02b3.txt
#  extracting: valid/wheaten_terrier_176_jpg.rf.616726b6201774f40db135aecd4e75ef.jpg
#  extracting: valid/wheaten_terrier_176_jpg.rf.616726b6201774f40db135aecd4e75ef.txt
#  extracting: valid/wheaten_terrier_17_jpg.rf.c3a86c5c0c6d1ecfdd2abb8fb2086d2d.jpg
#  extracting: valid/wheaten_terrier_17_jpg.rf.c3a86c5c0c6d1ecfdd2abb8fb2086d2d.txt
#  extracting: valid/wheaten_terrier_181_jpg.rf.84b60cb52f33f0118e371f5055d3ee51.jpg
#  extracting: valid/wheaten_terrier_181_jpg.rf.84b60cb52f33f0118e371f5055d3ee51.txt
#  extracting: valid/wheaten_terrier_183_jpg.rf.c610409f11296d6836b796a3666ce271.jpg
#  extracting: valid/wheaten_terrier_183_jpg.rf.c610409f11296d6836b796a3666ce271.txt
#  extracting: valid/wheaten_terrier_187_jpg.rf.d7736773fc850593105a6386dba9fbad.jpg
#  extracting: valid/wheaten_terrier_187_jpg.rf.d7736773fc850593105a6386dba9fbad.txt
#  extracting: valid/wheaten_terrier_190_jpg.rf.83e8d203655476ea15953f1b21ec9d98.jpg
#  extracting: valid/wheaten_terrier_190_jpg.rf.83e8d203655476ea15953f1b21ec9d98.txt
#  extracting: valid/yorkshire_terrier_107_jpg.rf.9a5099dd7a95f34ce3badff22bec240e.jpg
#  extracting: valid/yorkshire_terrier_107_jpg.rf.9a5099dd7a95f34ce3badff22bec240e.txt
#  extracting: valid/yorkshire_terrier_109_jpg.rf.b3923a700811211048698648f114b029.jpg
#  extracting: valid/yorkshire_terrier_109_jpg.rf.b3923a700811211048698648f114b029.txt
#  extracting: valid/yorkshire_terrier_111_jpg.rf.9b4d130ad0b24c5cba2b9c7deffaaf1c.jpg
#  extracting: valid/yorkshire_terrier_111_jpg.rf.9b4d130ad0b24c5cba2b9c7deffaaf1c.txt
#  extracting: valid/yorkshire_terrier_112_jpg.rf.5eba8e076d0cb0cccc083b773025da64.jpg
#  extracting: valid/yorkshire_terrier_112_jpg.rf.5eba8e076d0cb0cccc083b773025da64.txt
#  extracting: valid/yorkshire_terrier_118_jpg.rf.20137c93133a70073a0ae31b7ea5e1c7.jpg
#  extracting: valid/yorkshire_terrier_118_jpg.rf.20137c93133a70073a0ae31b7ea5e1c7.txt
#  extracting: valid/yorkshire_terrier_121_jpg.rf.06cd835d7e9b6fa7337d2d801d035815.jpg
#  extracting: valid/yorkshire_terrier_121_jpg.rf.06cd835d7e9b6fa7337d2d801d035815.txt
#  extracting: valid/yorkshire_terrier_127_jpg.rf.ffb5dcf976481fc92d0ba796509fe9da.jpg
#  extracting: valid/yorkshire_terrier_127_jpg.rf.ffb5dcf976481fc92d0ba796509fe9da.txt
#  extracting: valid/yorkshire_terrier_129_jpg.rf.ec5366a564069e286a0ad4a673a2781b.jpg
#  extracting: valid/yorkshire_terrier_129_jpg.rf.ec5366a564069e286a0ad4a673a2781b.txt
#  extracting: valid/yorkshire_terrier_12_jpg.rf.d8e79a027f2e1dd6080994043a23498d.jpg
#  extracting: valid/yorkshire_terrier_12_jpg.rf.d8e79a027f2e1dd6080994043a23498d.txt
#  extracting: valid/yorkshire_terrier_130_jpg.rf.c075d6caa5bac94a057913e2ceddf571.jpg
#  extracting: valid/yorkshire_terrier_130_jpg.rf.c075d6caa5bac94a057913e2ceddf571.txt
#  extracting: valid/yorkshire_terrier_137_jpg.rf.0bcaf9c437ca6b39b9739d020c05bfd7.jpg
#  extracting: valid/yorkshire_terrier_137_jpg.rf.0bcaf9c437ca6b39b9739d020c05bfd7.txt
#  extracting: valid/yorkshire_terrier_138_jpg.rf.4a1d96da93eefac6139c09c992d460bd.jpg
#  extracting: valid/yorkshire_terrier_138_jpg.rf.4a1d96da93eefac6139c09c992d460bd.txt
#  extracting: valid/yorkshire_terrier_139_jpg.rf.f0f2c77ecbf20a9aeeec621ce5f2de62.jpg
#  extracting: valid/yorkshire_terrier_139_jpg.rf.f0f2c77ecbf20a9aeeec621ce5f2de62.txt
#  extracting: valid/yorkshire_terrier_141_jpg.rf.28b2ce4aec30eb57de0efdee090ac8f3.jpg
#  extracting: valid/yorkshire_terrier_141_jpg.rf.28b2ce4aec30eb57de0efdee090ac8f3.txt
#  extracting: valid/yorkshire_terrier_144_jpg.rf.de5c6beb57a64256d6f83fb977daf802.jpg
#  extracting: valid/yorkshire_terrier_144_jpg.rf.de5c6beb57a64256d6f83fb977daf802.txt
#  extracting: valid/yorkshire_terrier_148_jpg.rf.f895f30cd12c837b2b62509a21d715ca.jpg
#  extracting: valid/yorkshire_terrier_148_jpg.rf.f895f30cd12c837b2b62509a21d715ca.txt
#  extracting: valid/yorkshire_terrier_150_jpg.rf.1c0b0b6071f63dcc253a9644ea2c3843.jpg
#  extracting: valid/yorkshire_terrier_150_jpg.rf.1c0b0b6071f63dcc253a9644ea2c3843.txt
#  extracting: valid/yorkshire_terrier_156_jpg.rf.6e3182c9b4d67257f58ff266132fd41c.jpg
#  extracting: valid/yorkshire_terrier_156_jpg.rf.6e3182c9b4d67257f58ff266132fd41c.txt
#  extracting: valid/yorkshire_terrier_159_jpg.rf.5aa7fe8cc5a65d8fb19935a6b67b7e06.jpg
#  extracting: valid/yorkshire_terrier_159_jpg.rf.5aa7fe8cc5a65d8fb19935a6b67b7e06.txt
#  extracting: valid/yorkshire_terrier_163_jpg.rf.47fee4c88fbbcfa1dc72efeb397745fa.jpg
#  extracting: valid/yorkshire_terrier_163_jpg.rf.47fee4c88fbbcfa1dc72efeb397745fa.txt
#  extracting: valid/yorkshire_terrier_170_jpg.rf.3eccdb4ef0d227ee6d23ff7f333ddd35.jpg
#  extracting: valid/yorkshire_terrier_170_jpg.rf.3eccdb4ef0d227ee6d23ff7f333ddd35.txt
#  extracting: valid/yorkshire_terrier_171_jpg.rf.5414d79d9fb658cc97bbf913efd70931.jpg
#  extracting: valid/yorkshire_terrier_171_jpg.rf.5414d79d9fb658cc97bbf913efd70931.txt
#  extracting: valid/yorkshire_terrier_172_jpg.rf.ebe385f95653072acc3db072575cf908.jpg
#  extracting: valid/yorkshire_terrier_172_jpg.rf.ebe385f95653072acc3db072575cf908.txt
#  extracting: valid/yorkshire_terrier_183_jpg.rf.f7cc5b225c772dd4568fc56da3a99813.jpg
#  extracting: valid/yorkshire_terrier_183_jpg.rf.f7cc5b225c772dd4568fc56da3a99813.txt
#  extracting: valid/yorkshire_terrier_188_jpg.rf.ae4a9b05c6f6e95d24578bac39f79d07.jpg
#  extracting: valid/yorkshire_terrier_188_jpg.rf.ae4a9b05c6f6e95d24578bac39f79d07.txt

# %%
""" Show labels of the dataset """
# %cat /content/train/_darknet.labels
# Out:
# cat
# dog

# %%
""" Import libraries """

import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torch.optim as optim
import torchvision.transforms.functional as FT
from torch.utils.data import DataLoader
from tqdm import tqdm
#from tqdm.auto import tqdm
import pandas as pd
import os
import PIL
import skimage
from skimage import io
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches
seed = 123
import cv2
torch.manual_seed(seed)
from collections import Counter
from time import sleep
import random
from google.colab.patches import cv2_imshow

# %%
""" Let us get the dataset information """

train_dir = '/content/train'
test_dir = '/content/test'

train_images = [file for file in os.listdir(train_dir) if file.endswith(".jpg")]
train_labels = [ file[:-4]+ ".txt"  for file in train_images]          

test_images = [file for file in os.listdir(test_dir) if file.endswith(".jpg")]
test_labels = [ file[:-4]+ ".txt"  for file in test_images]          

print(f"Train data contains {len(train_images)} images and {len(train_labels)} labels")
print(f"Test data contains {len(test_images)} images and {len(test_labels)} labels")
# Out:
# Train data contains 2576 images and 2576 labels
# Test data contains 368 images and 368 labels

# %%
""" The following is the example annotation.
    first value is class labels
    next four values are bounding box coordinates
    x, y, w, h normalized w.r.t to the image dimesions"""
    
# %cat /content/train/British_Shorthair_110_jpg.rf.686d228f221692ae81ed73d91946149f.txt
# Out:
# 0 0.535 0.44144144144144143 0.57 0.6486486486486487

# %% [markdown]
# Read about how to write Custom Dataloader in Pytorch:  https://pytorch.org/tutorials/beginner/data_loading_tutorial.html \
#
# Dataset class \
# torch.utils.data.Dataset is an abstract class representing a dataset. Your custom dataset should inherit Dataset and override the following methods:
#
# __len__ so that len(dataset) returns the size of the dataset. \
# __getitem__ to support the indexing such that dataset[i] can be used to get iith sample.

# %%
class LoadData(torch.utils.data.Dataset):
    
    def __init__(self, file_dir, S=7, B=2, C=2, transform=None):
        self.file_dir=file_dir
        self.images_list=[image for image in os.listdir(self.file_dir) if image.endswith(".jpg")]
        self.labels_list=[ file[:-4]+ ".txt"  for file in self.images_list]
        self.S=S
        self.B=B
        self.C=C
        self.transform=transform

    def __len__(self):
        return len(self.images_list)

    def __getitem__(self, idx):
        label_path= os.path.join(self.file_dir,self.labels_list[idx])
        label_file = open(label_path, 'r')

        #read labels
        boxes=[]
        for line in label_file.readlines():
            box = list(map(float,line.split()))
            boxes.append(box)

        boxes = torch.tensor(boxes)
        #read image
        img_path = os.path.join(self.file_dir, self.images_list[idx])
        image = Image.open(img_path)
        image = image.convert("RGB")

        if self.transform:
            # image = self.transform(image)
            image, boxes = self.transform(image, boxes)

        #convert center (x,y) w.r.t cell and write x,y,w,h , objectness and class label in label_matrix
        label_matrix = torch.zeros((self.S, self.S, self.C + 5 * self.B))

        for box in boxes:
            class_label, x_img, y_img, w, h = box
            class_label=int(class_label)

            i, j =  int(self.S * y_img) , int(self.S * x_img)
            x_cell, y_cell = self.S * x_img - j , self.S * y_img - i

            if label_matrix[i, j, self.C] == 0:
                # Set that there exists an object
                label_matrix[i, j, self.C] = 1
                # write box coordinates
                box_coordinates = torch.tensor([x_cell, y_cell, w, h])
                label_matrix[i, j, self.C + 1 : self.C + 5 ] = box_coordinates
                #Set class probability as 1
                label_matrix[i, j, class_label] = 1

        return image, label_matrix

# %%
architecture_config = [
    #Tuple: (kernel_size, number of filters, strides, padding)
    (7, 64, 2, 3),
    #"M" = Max Pool Layer
    "M",
    (3, 192, 1, 1),
    "M",
    (1, 128, 1, 0),
    (3, 256, 1, 1),
    (1, 256, 1, 0),
    (3, 512, 1, 1),
    "M",
    #List: [(tuple), (tuple), how many times to repeat]
    [(1, 256, 1, 0), (3, 512, 1, 1), 4],
    (1, 512, 1, 0),
    (3, 1024, 1, 1),
    "M",
    [(1, 512, 1, 0), (3, 1024, 1, 1), 2],
    (3, 1024, 1, 1),
    (3, 1024, 2, 1),
    (3, 1024, 1, 1),
    (3, 1024, 1, 1),
    #Doesnt include fc layers
]

# %%
# CNNBlock class includes CNN layer, batch normalization and then applies relu to get the output 
class CNNBlock(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(CNNBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, bias=False, **kwargs)
        self.batchnorm = nn.BatchNorm2d(out_channels)
        self.leakyrelu = nn.LeakyReLU(0.1)
        
    def forward(self, x):
        return self.leakyrelu(self.batchnorm(self.conv(x)))

#here we define YOLOv1  
class YoloV1(nn.Module):
    def __init__(self, in_channels=3, **kwargs):
        super(YoloV1, self).__init__()
        self.architecture = architecture_config
        self.in_channels = in_channels
        self.darknet = self._create_conv_layers(self.architecture)
        self.fcs = self._create_fcs(**kwargs)
        
    def forward(self, x):
        x = self.darknet(x)
        return self.fcs(torch.flatten(x, start_dim=1))
    
    #create darknet
    def _create_conv_layers(self, architecture):
        layers = []
        in_channels = self.in_channels
        
        for x in architecture:
            if type(x) == tuple:
                layers += [CNNBlock(in_channels, x[1], kernel_size=x[0], stride=x[2], padding=x[3])]
                in_channels = x[1]
            elif type(x) == str:
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            elif type(x) == list:
                conv1 = x[0] #Tuple
                conv2 = x[1] #Tuple
                repeats = x[2] #Int
                
                for _ in range(repeats):
                    layers += [CNNBlock(in_channels, conv1[1], kernel_size=conv1[0], stride=conv1[2], padding=conv1[3])]
                    layers += [CNNBlock(conv1[1], conv2[1], kernel_size=conv2[0], stride=conv2[2], padding=conv2[3])]
                    in_channels = conv2[1]
                    
        return nn.Sequential(*layers)
    
    #create fully connected layer
    def _create_fcs(self, split_size, num_boxes, num_classes):
        S, B, C = split_size, num_boxes, num_classes
        return nn.Sequential(nn.Flatten(),
                             nn.Linear(1024 * S * S, 600), 
                             nn.Dropout(0.0), 
                             nn.LeakyReLU(0.1),
                             nn.Linear(600, S * S * (C + B * 5)),
                             nn.Sigmoid())                           #Original paper uses nn.Linear(1024 * S * S, 4096) not 496. Also the last layer will be reshaped to (S, S, 13) where C+B*5 = 13

# %%
""" This function calculates intersection over union 
    input parameters: Prediction boxes(boxes_preds) predicted for a batch of input i.e, of size (batch_size,S,S, 4)
                      Ground truth boxes(boxes_gt) for a batch of input i.e, of size (batch_size,S,S,4)
                      centroid_format ='image' or 'cell' 
                      if the center of bounding box (x,y) are offset w.r.t cell then centroid_format should be kept equal to 'cell'.Hence, it will
                      be first converted w.r.t image via. function convert_boxes_wrt_image and then passed for IOU calculation.

    output: IOU for all input pairs of prediction and ground truth boxes i.e, of size (batch_size,S,S,1)
    (0,1,2,3) == (x,y,w,h)
"""

def IOU(boxes_preds, boxes_gt,  centroid_format='image'):
    
    #change the box centroid coordinates (x,y) w.r.t image if they are w.r.t cell 
    if centroid_format == 'cell':
        boxes_preds = convert_boxes_wrt_image(boxes_preds)
        boxes_gt = convert_boxes_wrt_image(boxes_gt)

    #box-1 left-top(x1,y1) and right-bottom(x2,y2) coordinate points
    b1_x1 = boxes_preds[...,0:1] - boxes_preds[...,2:3]/2    # center_x - w/2
    b1_x2 = boxes_preds[...,0:1] + boxes_preds[...,2:3]/2    # center_x + w/2
    b1_y1 = boxes_preds[...,1:2] - boxes_preds[...,3:4]/2    # center_y - h/2
    b1_y2 = boxes_preds[...,1:2] + boxes_preds[...,3:4]/2    # center_y + h/2

    #box-2 left-top(x1,y1) and right-bottom(x2,y2) coordinate points
    b2_x1 = boxes_gt[...,0:1] - boxes_gt[...,2:3]/2    # center_x - w/2
    b2_x2 = boxes_gt[...,0:1] + boxes_gt[...,2:3]/2    # center_x + w/2
    b2_y1 = boxes_gt[...,1:2] - boxes_gt[...,3:4]/2    # center_y - h/2
    b2_y2 = boxes_gt[...,1:2] + boxes_gt[...,3:4]/2    # center_y + h/2

    #left-top(x1,y1) and right-bottom(x2,y2) coordinate points of intersection box
    x1 = torch.max(b1_x1,b1_x1)
    x2 = torch.min(b1_x2,b2_x2)
    y1 = torch.max(b1_y1,b2_y1)
    y2 = torch.min(b1_y2,b2_y2)

    #.clamp(0) is for the case when they don't intersect. Since when they don't intersect, one of these will be negative so that should become 0
    intersection_area = (x2 - x1).clamp(0) * (y2 - y1).clamp(0)

    #Area of box-1 and box-2
    box1_area = abs((b1_x2 - b1_x1) * (b1_y2 - b1_y1))
    box2_area = abs((b2_x2 - b2_x1) * (b2_y2 - b2_y1))

    iou = intersection_area / (box1_area + box2_area - intersection_area + 1e-6)

    return iou

""" convert_boxes_wrt_image , this function takes input boxes whose centroid format are w.r.t cell and convert it w.r.t image
    input:
    batch_boxes (tensor): Predicted or Ground truth boxes for a batch and it is a tensor of size (batch_size,S,S,4)
    S (integer) : Split size for algorithm
    
    output (tensor): Boxes whose centroid are w.r.t 'image' of size (batch_size, S,S,4)
"""

def convert_boxes_wrt_image(batch_boxes, S=7):

    #cell_indices is 'j' with size (N,S,S,1) and cell_indices.permute(0, 2, 1, 3) is 'i' with size (N,S,S,1)
    batch_size = batch_boxes.shape[0]
    cell_indices = torch.arange(7).repeat(batch_size, 7, 1).unsqueeze(-1).to(DEVICE)      #(N,S,S,1)
    x = 1 / S * (batch_boxes[..., :1] + cell_indices)
    y = 1 / S * (batch_boxes[..., 1:2] + cell_indices.permute(0, 2, 1, 3))
    w_h = batch_boxes[..., 2:4]

    converted_bboxes = torch.cat((x, y, w_h), dim=-1)  #(N,S,S,4)

    return converted_bboxes

# %%
""" This function the loss
    Input: Predictions of size (batch_size, S,S, 5*B+C) 
           Ground truth targets of size (batch_size, S * S* (5*B+C))
    Output: Mean Square Error defined in YOLOv1 paper (hence, a float value)"""

class YOLOLoss(nn.Module):
    def __init__(self, S=7, B=2, C=2):
        super(YOLOLoss,self).__init__()
        self.mse = nn.MSELoss(reduction = 'sum')
        self.S = S
        self.B = B
        self.C = C
        self.lambda_noobj = 0.5
        self.lambda_coord = 5

    def forward(self, predictions, ground_truths):
        #reshape prediction output from (batch_size , 588) to (batch_size, 7,7,12)
        predictions = predictions.reshape(-1, self.S, self.S, 5*self.B+self.C ) 
        

        #get the best box i.e, box responsible for prediction out of 2 predicted bounding box
        iou_b1 = IOU(predictions[...,self.C + 1 : self.C + 5], ground_truths[..., self.C + 1 : self.C + 5],centroid_format='cell')  #(N,S,S,1)
        iou_b2 = IOU(predictions[...,self.C + 6 : ], ground_truths[..., self.C + 1 : self.C + 5],centroid_format='cell')  #(N,S,S,1)
        
        ious = torch.cat([iou_b1.unsqueeze(0), iou_b2.unsqueeze(0)], dim=0)  #(2,N,S,S,1)
        
        iou_maxes, bestbox = torch.max(ious, dim=0)   #dimension of both iou_maxes and bestbox are (N,S,S,1)

        exists_box = ground_truths[..., self.C : self.C + 1 ] # (N,S,S,1)
       
       
        #Calculate box loss

        box_pred =exists_box * (
                  ( bestbox * predictions[...,self.C + 6 :] + (1- bestbox) * predictions[...,self.C + 1 : self.C + 5])   #(N,S,S,4)
        )

        box_gt = exists_box * ground_truths[..., self.C + 1 : self.C + 5] #(N,S,S,4)
        
        ## take square root of width and height
        box_pred[..., 2:4] = torch.sign(box_pred[..., 2:4]) * torch.sqrt(torch.abs(box_pred[..., 2:4] + 1e-6))

        box_gt[..., 2:4] = torch.sqrt(box_gt[..., 2:4])

        box_loss = self.mse(torch.flatten(box_pred, end_dim=-2), 
                            torch.flatten(box_gt, end_dim=-2))      # float 

        #Calculate object loss

        pred_C = bestbox * predictions[..., self.C + 5 : self.C + 6] + (1-bestbox) * predictions[..., self.C : self.C + 1] #(N,S,S,1)
        gt_C = ground_truths[..., self.C : self.C + 1] #(N,S,S,1)

        object_loss = self.mse(torch.flatten(exists_box * pred_C, end_dim=-2), 
                               torch.flatten(exists_box * gt_C, end_dim=-2))     # float

       #Calculate no object loss

        no_object_loss = self.mse(
            torch.flatten((1 - exists_box) * predictions[..., self.C:self.C + 1], end_dim=-2),    #(N*S*S,1)
            torch.flatten((1 - exists_box) * ground_truths[..., self.C:self.C + 1], end_dim=-2)) 

        no_object_loss += self.mse(
            torch.flatten((1 - exists_box) * predictions[..., self.C + 5:self.C + 6], end_dim=-2),
            torch.flatten((1 - exists_box) * ground_truths[..., self.C:self.C + 1], end_dim=-2)) #no_object_loss is float 

        #Class probability loss

        class_loss = self.mse(torch.flatten(exists_box * predictions[..., :self.C], end_dim=-2), 
                              torch.flatten(exists_box * ground_truths[..., :self.C], end_dim=-2)) 
        
        #Total loss
        loss = ( self.lambda_coord * box_loss  # first two rows in paper
             + object_loss  # third row in paper
             + self.lambda_noobj * no_object_loss  # forth row
             + class_loss)  # fifth row
        
        return loss

# %%
def train_fn(train_loader, model, optimizer, loss_fn , epoch):
    mean_loss = []
    with tqdm(train_loader, unit="batch") as loop:     #tqdm to show progress bar for each training epoch
        loop.set_description(f"Epoch {epoch}")
        for batch_idx, (x,y) in enumerate(loop):
            x , y = x.to(DEVICE) , y.to(DEVICE)
            out = model(x)
            loss = loss_fn(out,y)
            mean_loss.append(loss.item())
            optimizer.zero_grad()          #all gradient should be zero in next epoch and should not carry previous gradients
            loss.backward()                #calculates the gradient update for each layer
            optimizer.step()               #update the weights  
            sleep(0.1)
        print(f"Mean loss was {sum(mean_loss) / len(mean_loss)}")

# %%
""" Compose function is responsible for preprocessing , it is passed as a "transform" in LoadData() class 
    Input arguments: A list containing transformation functions
    Output: Transformation functions are applied to the input image and label and outputted """
class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, img, bboxes):
        for t in self.transforms:
            img, bboxes = t(img), bboxes 

        return img, bboxes


transform = Compose([transforms.Resize((448, 448)), transforms.ToTensor()])

# %%
def save_checkpoint(state, filename="my_checkpoint.pth"):
    print("=> Saving checkpoint")
    torch.save(state, filename)

# %%
def load_checkpoint(checkpoint, model, optimizer):
    print("=> Loading checkpoint")
    model.load_state_dict(checkpoint["state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer"])

# %%
"""Input: label_matrix of size (batch_size, S,S, 5*B+C)
   Output type-list : Contains elements as list. Each list has values as: [class_int, prob ,x_img ,y_img, w_img, h_img]
"""

def tensor_to_boxes(in_tensor ,S=7 ,B=2 ,C=2):
    bboxes1 = in_tensor[..., C + 1:C + 5] 
    bboxes2 = in_tensor[..., C + 6: ]
    
    #get best boxes
    scores = torch.cat((in_tensor[..., C:C + 1].unsqueeze(0), in_tensor[..., C + 5:C + 6].unsqueeze(0)), dim=0)
    max_scores, best_box = torch.max(scores, dim=0)  #both are of size (N,S,S,1)
    best_boxes = bboxes1 * (1 - best_box) + best_box * bboxes2  #(N,S,S,4)

    converted_bboxes = convert_boxes_wrt_image(best_boxes)  #(N,S,S,4)
    predicted_class = in_tensor[..., :C].argmax(-1).unsqueeze(-1)  #(N,S,S,1)  

    converted_preds = torch.cat((predicted_class, max_scores, converted_bboxes), dim=-1)  #(N,S,S,6)
    
    converted_preds = converted_preds.reshape(-1, S * S, 6)
    converted_preds[..., 0] = converted_preds[..., 0].long()
    all_bboxes = [] 

    for ex_idx in range(converted_preds.shape[0]):
        bboxes = []

        for bbox_idx in range(S * S):   #S*S = total no. of cells in SxS grid
            bboxes.append([x.item() for x in converted_preds[ex_idx, bbox_idx, :]])
        all_bboxes.append(bboxes) 

    return all_bboxes  # (N,49,6)

# %%
"""
    Does Non Max Suppression given bboxes
    Parameters:
        bboxes (list): list of lists containing all bboxes with each bboxes
        specified as [class_int, prob_score, x_img, y_img, w_img, h_img]
        iou_threshold (float): threshold where predicted bboxes is correct
        threshold (float): threshold to remove predicted bboxes (independent of IoU) 
        box_format (str): "midpoint" or "corners" used to specify bboxes
    Returns:
        list: bboxes after performing NMS given a specific IoU threshold
    """

def non_max_suppression(bboxes, iou_threshold, threshold): 
    
    assert type(bboxes) == list

    bboxes = [box for box in bboxes if box[1] > threshold]
    bboxes = sorted(bboxes, key=lambda x: x[1], reverse=True)
    bboxes_after_nms = []

    while bboxes:
        chosen_box = bboxes.pop(0)
        
        #following loop discards those box whose class is same as chosen_box and iou w.r.t chosen box is > iou_threshold
        bboxes = [
            box
            for box in bboxes
            if box[0] != chosen_box[0]                 #if the class is not same 
            or IOU(torch.tensor(chosen_box[2:]),torch.tensor(box[2:])) < iou_threshold
        ] 

        bboxes_after_nms.append(chosen_box)

    return bboxes_after_nms

# %%
""" This function get_bboxes takes dataset (train/test), model, iou_threshold, threshold as input.
    It sets the model to evaluation mode and predicts the output for given dataset and convert the prediction tensor to
    list of box information as [train_idx, class_int, prob , x_img, y_img, w_img, h_img  ] and outputs it for further use in 
    model evaluation for mAP.
"""
def get_bboxes(loader,model,iou_threshold, threshold,pred_format="cells",device="cuda", S=7, B=2, C=2 , train = True):
    all_pred_boxes = []
    all_true_boxes = []
    # make sure model is in eval before get bboxes
    model.eval()
    train_idx = 0 

    for batch_idx, (x, labels) in enumerate(loader):
        x = x.to(device)
        labels = labels.to(device)

        with torch.no_grad():
            predictions = model(x)

        batch_size = x.shape[0]
        true_bboxes = tensor_to_boxes(labels)  #converts tensor to list of boxes
        predictions = predictions.reshape(-1, S, S, 5*B + C )  #(N,588) --> (N,S,S,5*B+C) because tensor_to_boxes expects this size of i/p
        bboxes = tensor_to_boxes(predictions)

        for idx in range(batch_size):
            nms_boxes = non_max_suppression(
                bboxes[idx],
                iou_threshold=iou_threshold,
                threshold=threshold
                )

            for nms_box in nms_boxes:
                all_pred_boxes.append([train_idx] + nms_box)

            for box in true_bboxes[idx]:
                # many will get converted to 0 pred
                if box[1] > threshold:
                    all_true_boxes.append([train_idx] + box)

            train_idx += 1
    
    if train == True:
        model.train()

    return all_pred_boxes, all_true_boxes

# %%
""" This function finds the mean average precision over entire training epoch 
    and can also be used for testing.
    Input parameters:
    pred_boxes (list): list of lists containing all predicted bboxes with each bboxes
                        specified as [train_idx, class_int, prob, x_img, y_img, w_img, h_img]
    true_boxes (list): list of lists containing all ground truth bboxes with each bboxes
                        specified as [train_idx, class_int, prob, x_img, y_img, w_img, h_img]
    iou_threshold: threshold where predicted bboxes is correct
    num_classes= number of classes
"""
def mean_average_precision(pred_boxes, true_boxes, iou_threshold=0.5, num_classes=2):

    average_precisions = []   #to store AP corresponding to all classes
    epsilon = 1e-6            # used for numerical stability
    
    for c in range(num_classes):
        #take all detection bbox and ground truth bbox belonging to class c
        detections=[det for det in pred_boxes if det[1] == c]
        ground_truths=[grt for grt in true_boxes if grt[1] == c] 

        #Initialize a dictionary with (key,value) as (train_idx, tensor of zeros of size number of ground truth 
        #bbox for image at train_idx). This is to keep track whether detection w.r.t this ground truth bbox is 
        #covered. Because we can have only one TP detection bbox w.r.t one ground truth bbox.

        ##foll will give dict with key=train_idx and value = no. of times train_idx appreared in ground_truths
        #Example: amount_bboxes = {0:3, 1:5}
        amount_bboxes = Counter([gt[0] for gt in ground_truths]) 
        #Now change to tensor of zeros-Example:ammount_bboxes = {0:torch.tensor[0,0,0], 1:torch.tensor[0,0,0,0,0]}
        for key, val in amount_bboxes.items():
            amount_bboxes[key] = torch.zeros(val) 

        # sort by box probabilities which is index 2
        detections.sort(key=lambda x: x[2], reverse=True)
        TP = torch.zeros((len(detections)))        #initialize a tensor of zeros of size (len(detections))
        FP = torch.zeros((len(detections)))
        total_true_bboxes = len(ground_truths) 

        # If none exists for this class then we can safely skip
        if total_true_bboxes == 0:
            continue

        for detection_idx, detection in enumerate(detections):
            #get all ground truth bbox belonging to same image(train_idx) to with detection belongs to
            ground_truth_img = [bbox for bbox in ground_truths if bbox[0] == detection[0]] 

            #from all these ground truth bbox of this image get the best bbox that detection is representing
            best_iou = 0
            for idx, gt in enumerate(ground_truth_img):
                iou = IOU(torch.tensor(detection[3:]),torch.tensor(gt[3:]))
                if iou > best_iou:
                    best_iou = iou
                    best_gt_idx = idx
            
            #check whether best_iou is > iou_threshold and
            #this ground truth bbox is not covered before if yes this detection is TP
            if best_iou > iou_threshold:
                if  amount_bboxes[detection[0]][best_gt_idx]==0:
                    TP[detection_idx] = 1
                    amount_bboxes[detection[0]][best_gt_idx] = 1
                else:
                    FP[detection_idx] = 1
            else:
                FP[detection_idx] = 1

        TP_cumsum = torch.cumsum(TP, dim=0)
        FP_cumsum = torch.cumsum(FP, dim=0)
        recalls = TP_cumsum / (total_true_bboxes + epsilon)
        precisions = torch.divide(TP_cumsum, (TP_cumsum + FP_cumsum + epsilon))
        precisions = torch.cat((torch.tensor([1]), precisions))
        recalls = torch.cat((torch.tensor([0]), recalls))
        # torch.trapz for numerical integration
        average_precisions.append(torch.trapz(precisions, recalls))        

    return sum(average_precisions) / len(average_precisions)

# %%
LEARNING_RATE = 2e-5
DEVICE = "cuda" if torch.cuda.is_available else "cpu"
BATCH_SIZE = 16  #16 # 64 in original paper but resource exhausted error otherwise.
WEIGHT_DECAY = 0
EPOCHS = 20
NUM_WORKERS = 2
PIN_MEMORY = True
LOAD_MODEL = False
LOAD_MODEL_FILE = "model.pth"

# %%
def main():
    model = YoloV1(split_size=7, num_boxes=2, num_classes=2).to(DEVICE)
    optimizer = optim.Adam(
        model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    )
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, factor=0.1, patience=3, mode='max', verbose=True)
    loss_fn = YOLOLoss()

    if LOAD_MODEL:
        load_checkpoint(torch.load(LOAD_MODEL_FILE), model, optimizer)

    train_dataset = LoadData(file_dir= '/content/train',transform=transform)

    test_dataset = LoadData(file_dir='/content/test',transform=transform)

    train_loader = DataLoader(
        dataset=train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        drop_last=False,
    )

    test_loader = DataLoader(
        dataset=test_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        drop_last=False,
    )

    for epoch in range(EPOCHS):
        
        train_fn(train_loader, model, optimizer, loss_fn, epoch)
        
        pred_boxes, target_boxes = get_bboxes(
            train_loader, model, iou_threshold=0.5, threshold=0.4, device=DEVICE )

        mean_avg_prec = mean_average_precision(
            pred_boxes, target_boxes, iou_threshold=0.5)
        print(f"Train mAP: {mean_avg_prec}")
        
        scheduler.step(mean_avg_prec)
    
    checkpoint = {
            "state_dict": model.state_dict(),
            "optimizer": optimizer.state_dict(),
    }
    save_checkpoint(checkpoint, filename=LOAD_MODEL_FILE) 
    
if __name__ == "__main__":
    main()
# Out:
# Epoch 0: 100%|██████████| 161/161 [00:57<00:00,  2.79batch/s]
# Mean loss was 44.052795576012656
# Epoch 1:   0%|          | 0/161 [00:00<?, ?batch/s]
# Train mAP: 0.02153470367193222
# Epoch 1: 100%|██████████| 161/161 [00:57<00:00,  2.78batch/s]
# Mean loss was 32.11251536067228
# Epoch 2:   0%|          | 0/161 [00:00<?, ?batch/s]
# Train mAP: 0.07187370955944061
# Epoch 2: 100%|██████████| 161/161 [00:57<00:00,  2.79batch/s]
# Mean loss was 27.565581007773833
# Epoch 3:   0%|          | 0/161 [00:00<?, ?batch/s]
# Train mAP: 0.25845736265182495
# Epoch 3: 100%|██████████| 161/161 [00:57<00:00,  2.79batch/s]
# Mean loss was 23.268739048738656
# Epoch 4:   0%|          | 0/161 [00:00<?, ?batch/s]
# Train mAP: 0.3366401195526123
# Epoch 4: 100%|██████████| 161/161 [00:57<00:00,  2.79batch/s]
# Mean loss was 18.86909055413667
# Epoch 5:   0%|          | 0/161 [00:00<?, ?batch/s]
# Train mAP: 0.45115986466407776
# Epoch 5: 100%|██████████| 161/161 [00:57<00:00,  2.80batch/s]
# Mean loss was 15.66784277613859
# Epoch 6:   0%|          | 0/161 [00:00<?, ?batch/s]
# Train mAP: 0.5672346353530884
# Epoch 6: 100%|██████████| 161/161 [00:57<00:00,  2.79batch/s]
# Mean loss was 13.040108834734614
# Epoch 7:   0%|          | 0/161 [00:00<?, ?batch/s]
# Train mAP: 0.7270433306694031
# Epoch 7: 100%|██████████| 161/161 [00:57<00:00,  2.79batch/s]
# Mean loss was 10.389480792217373
# Epoch 8:   0%|          | 0/161 [00:00<?, ?batch/s]
# Train mAP: 0.7781316637992859
# Epoch 8: 100%|██████████| 161/161 [00:57<00:00,  2.79batch/s]
# Mean loss was 8.687038777037436
# Epoch 9:   0%|          | 0/161 [00:00<?, ?batch/s]
# Train mAP: 0.8329451680183411
# Epoch 9: 100%|██████████| 161/161 [00:57<00:00,  2.79batch/s]
# Mean loss was 7.487148059821277
# Train mAP: 0.827751636505127
# => Saving checkpoint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
shutil.copy('/content/model.pth', '/content/drive/MyDrive/SpanIdea/program_from_scratch/weights')
# Out:
# '/content/drive/MyDrive/SpanIdea/program_from_scratch/weights/model.pth'

# %%
""" Evaluate the model on test dataset"""

model = YoloV1(split_size=7, num_boxes=2, num_classes=2).to(DEVICE)
#LOAD_MODEL_FILE = '/content/model.pth'
LOAD_MODEL_FILE = '/content/drive/MyDrive/SpanIdea/YOLO_from_scratch/weights/model_22.7_mAP.pth'

optimizer = optim.Adam(
       model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY
   )
load_checkpoint(torch.load(LOAD_MODEL_FILE), model, optimizer)

model.eval()
#Get mAP on test data:

test_dataset = LoadData(file_dir='/content/test',transform=transform)

test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

pred_boxes, target_boxes = get_bboxes(test_loader, model, iou_threshold=0.5, threshold=0.4, device=DEVICE , 
                                      train = False)

mean_avg_prec = mean_average_precision(pred_boxes, target_boxes, iou_threshold=0.5)
print(f"Test mAP: {mean_avg_prec}")
# Out:
# => Loading checkpoint
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Test mAP: 0.22777032852172852

# %%
""" This function assigns unique color for each class by choosing random colors """

def class_colors(names):
    """
    Create a dict with one random BGR color for each
    class name
    """
    return {name: (
        random.randint(0, 255),
        random.randint(0, 255),
        random.randint(0, 255)) for name in names}


class_names=['cat','dog']
colors=class_colors(class_names)

# %%
""" Visualize the result by drawing predicted bounding box on the input image  """

S=7
B=2
C=2
img_path = '/content/test/Abyssinian_131_jpg.rf.e8acfb60e4d01529586b9d81930b35a2.jpg'
image = Image.open(img_path)
image = image.convert("RGB")
image = image.resize((448,448)) 
tran = transforms.ToTensor()
x = tran(image)
x = x.unsqueeze(0)
predictions = model(x.to(DEVICE))
predictions = predictions.reshape(-1, S, S, 5*B + C )
bboxes = tensor_to_boxes(predictions)

batch_size = len(bboxes)
for idx in range(batch_size):
    nms_boxes = non_max_suppression(
                bboxes[idx],
                iou_threshold=0.5,
                threshold=0.2
                ) 

img = cv2.imread(img_path)
img = cv2.resize(img, (448,448))
width , height, ch = img.shape
for box in nms_boxes:
    x1 = int(width* (box[2] - box[4]/2))
    x2 = int(width* (box[2] + box[4]/2))
    y1 = int(height* (box[3] - box[5]/2))
    y2 = int(height* (box[3] + box[5]/2))
    label = class_names[int(box[0])]
    confidence = float(box[1]) 
    shape = [x1,y1,x2,y2]
    #draw bounding box and write confidence and text
    cv2.rectangle(img, (x1, y1), (x2, y2), colors[label], 2)
    cv2.putText(img, "{} [{:.2f}]".format(label, float(confidence)),
                    (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                    colors[label], 2)
cv2_imshow(img)


# save image
cv2.imwrite('output.jpg', img)
# Out:
# <PIL.Image.Image image mode=RGB size=448x448 at 0x7F2FB107EB50>
# True
